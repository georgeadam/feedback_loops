# %% [markdown]
# # Polya Urn Experiments

# %% [markdown]
# To determine if the Polya urn model is appropriate for our application, we need to compare the evolution of our model's FPR to the evolution of the ratio of positive and negative labels in our dataset.
#
# The main (potential) issue with our current setup of the urn model is that the probability of sampling a given class changes. Though this could be interpreted as representing the fact that it's not just new samples who's labels can switch, but also previous true negatives may become false positives since we are forcing the model to fit biased noisy labels.
#
# Specifically, this is what we are modelling
#
# $$
#     \begin{align}
#         D^{(t)} &:= \mathrm{Dataset \: at \: time \: t}\\
#         D^{(t)}_{TN} &:= \{\mathrm{x_{i} \in D^{(t)} | f(x_{i}) = 0 \land y_i = 0}\}
#     \end{align}
# $$
#
# $$
#     \begin{equation}
#         p(f(x_i) = 1 | y_i = 0) = p(fp) / p(y_i = 0)
#     \end{equation}
# $$

# %%
import numpy as np

# %% [markdown]
# ## True Random Process

# %%
iterations = 1000000
init_samples = 10000
pos_p = 0.5
neg_p = 1 - pos_p

fpr = 0.01
tpr = 0.49
fnr = 0.01
tnr = 0.49

switch_prob = 0.99

model_preds = np.array([int(init_samples * fpr), int(init_samples * tpr), int(init_samples * fnr), int(init_samples * tnr)])
labels = np.array([int(init_samples * neg_p), int(init_samples * pos_p)])

# %%
for i in range(iterations):
    new_sample = np.random.choice([0, 1], 1, p=[neg_p, pos_p])
    
    if new_sample == 0:
        p_1_0 = fpr / neg_p
        pred = np.random.choice([0, 1], 1, p=[1 - p_1_0, p_1_0])
        
        if pred == 1:
            model_preds[0] += 1
            labels[1] += 1
            
            switch = np.random.choice([0, 1], 1, p=[1 - switch_prob, switch_prob])
            
            if switch == 1 and model_preds[3] > 0:
                model_preds[3] -= 1
                model_preds[0] += 1
        else:
            model_preds[3] += 1
            labels[0] += 1
    else:
        p_0_1 = fnr / pos_p
        pred = np.random.choice([0, 1], 1, p=[p_0_1, 1 - p_0_1])
        
        if pred == 1:
            model_preds[1] += 1
        else:
            model_preds[2] += 1

        labels[1] += 1
        
    fpr = model_preds[0] / np.sum(model_preds)
    fnr = model_preds[2] / np.sum(model_preds)
    
    if i % 1000 == 0:
        print("Ratio of positive labels: {} | FPR: {}".format(float(labels[1]) / (labels[0] + labels[1]), fpr))
# Out:
# Ratio of positive labels: 0.5000499950005 | FPR: 0.009999000099990002
# Ratio of positive labels: 0.501136260339969 | FPR: 0.01127170257249341
# Ratio of positive labels: 0.502374802099825 | FPR: 0.013082243146404467
# Ratio of positive labels: 0.5027305591877548 | FPR: 0.013768171679101607
# Ratio of positive labels: 0.5045353903292622 | FPR: 0.015498892936218842
# Ratio of positive labels: 0.5034997666822212 | FPR: 0.01566562229184721
# Ratio of positive labels: 0.5045934629085682 | FPR: 0.016686457096431472
# Ratio of positive labels: 0.5051467560731722 | FPR: 0.016763719781189342
# Ratio of positive labels: 0.5055274706960724 | FPR: 0.018387867340703294
# Ratio of positive labels: 0.5057102257775906 | FPR: 0.019104257670648914
# Ratio of positive labels: 0.5063246837658117 | FPR: 0.01974901254937253
# Ratio of positive labels: 0.506785391171849 | FPR: 0.020713299366696823
# Ratio of positive labels: 0.5084768874142085 | FPR: 0.020680878141902642
# Ratio of positive labels: 0.5091082996391462 | FPR: 0.02178166166688405
# Ratio of positive labels: 0.5093537769259614 | FPR: 0.023790675388525476
# Ratio of positive labels: 0.5099796008159674 | FPR: 0.024639014439422423
# Ratio of positive labels: 0.5093650244221376 | FPR: 0.025460559209261182
# Ratio of positive labels: 0.509795933483945 | FPR: 0.026591607718232657
# Ratio of positive labels: 0.5101246384057713 | FPR: 0.027856147994714475
# Ratio of positive labels: 0.5111892693355402 | FPR: 0.029861039274507777
# Ratio of positive labels: 0.5116496116796106 | FPR: 0.030265657811406287
# Ratio of positive labels: 0.5123060546433986 | FPR: 0.030676429792587338
# Ratio of positive labels: 0.513108965344833 | FPR: 0.03193650198431299
# Ratio of positive labels: 0.5128329444562286 | FPR: 0.0326656767976728
# Ratio of positive labels: 0.5133378430046175 | FPR: 0.03346960383518132
# Ratio of positive labels: 0.513842461643953 | FPR: 0.034370446558669755
# Ratio of positive labels: 0.5144857087303131 | FPR: 0.035082358823366015
# Ratio of positive labels: 0.5147158184913921 | FPR: 0.035539580011351046
# Ratio of positive labels: 0.5153022288887135 | FPR: 0.036420094208047156
# Ratio of positive labels: 0.5160124099382067 | FPR: 0.03738365682931207
# Ratio of positive labels: 0.5169370765730856 | FPR: 0.038374040648983775
# Ratio of positive labels: 0.5168166630082193 | FPR: 0.03948684178434672
# Ratio of positive labels: 0.517130544510845 | FPR: 0.04021332825408919
# Ratio of positive labels: 0.5174995930327202 | FPR: 0.04088277016813562
# Ratio of positive labels: 0.5182154951023841 | FPR: 0.041839958182768575
# Ratio of positive labels: 0.518788471367303 | FPR: 0.04299904446567854
# Ratio of positive labels: 0.5191191495837048 | FPR: 0.04445555531401491
# Ratio of positive labels: 0.5194570328290887 | FPR: 0.04533946086253484
# Ratio of positive labels: 0.5199683339930418 | FPR: 0.04606154038457532
# Ratio of positive labels: 0.5202955041733842 | FPR: 0.046917409848778596
# Ratio of positive labels: 0.5208495830083398 | FPR: 0.048419031619367614
# Ratio of positive labels: 0.5217936903197976 | FPR: 0.04939118840807043
# Ratio of positive labels: 0.5221438049268283 | FPR: 0.04982596488529067
# Ratio of positive labels: 0.5228957944189733 | FPR: 0.0508480972057131
# Ratio of positive labels: 0.5236940056665618 | FPR: 0.0517953371233866
# Ratio of positive labels: 0.5240268358757113 | FPR: 0.05259904365375175
# Ratio of positive labels: 0.5244906340958198 | FPR: 0.05339190371600507
# Ratio of positive labels: 0.524973246083402 | FPR: 0.05429729302994684
# Ratio of positive labels: 0.5249737073498733 | FPR: 0.05522318580714126
# Ratio of positive labels: 0.5257876985135845 | FPR: 0.0562193861120998
# Ratio of positive labels: 0.5263245612573124 | FPR: 0.05704904918251363
# Ratio of positive labels: 0.5267454631891281 | FPR: 0.05832691267356273
# Ratio of positive labels: 0.5273140755794261 | FPR: 0.059128078579377755
# Ratio of positive labels: 0.5274995634989921 | FPR: 0.059951429342391394
# Ratio of positive labels: 0.528304245246168 | FPR: 0.060624052749175796
# Ratio of positive labels: 0.5292226273441947 | FPR: 0.06147597729265704
# Ratio of positive labels: 0.5295071286798685 | FPR: 0.06257480947258375
# Ratio of positive labels: 0.5301114908732706 | FPR: 0.06384979328666736
# Ratio of positive labels: 0.5300069116630638 | FPR: 0.06455787414890958
# Ratio of positive labels: 0.530427095259489 | FPR: 0.0652454312256344
# Ratio of positive labels: 0.5309067013328381 | FPR: 0.06602762817674034
# Ratio of positive labels: 0.5313587132575598 | FPR: 0.0673229954507683
# Ratio of positive labels: 0.5319231677337815 | FPR: 0.06780461382480799
# Ratio of positive labels: 0.5320612046410323 | FPR: 0.06887576882508459
# Ratio of positive labels: 0.5328441507547196 | FPR: 0.07022878069215281
# Ratio of positive labels: 0.5335128864948467 | FPR: 0.07123905014599806
# Ratio of positive labels: 0.5337035039012644 | FPR: 0.07202536808726201
# Ratio of positive labels: 0.5343826703549305 | FPR: 0.07289515720575057
# Ratio of positive labels: 0.5349418597197472 | FPR: 0.07399905129421418
# Ratio of positive labels: 0.5352463892862116 | FPR: 0.07513828938874191
# Ratio of positive labels: 0.5354183072711591 | FPR: 0.07612404844939438
# Ratio of positive labels: 0.5359933827977432 | FPR: 0.07691263070826286
# Ratio of positive labels: 0.5364446775039329 | FPR: 0.07770636943451908
# Ratio of positive labels: 0.5369814821508174 | FPR: 0.0784689341092276
# Ratio of positive labels: 0.5373269365840883 | FPR: 0.07936810276068142
# Ratio of positive labels: 0.537523087963671 | FPR: 0.07997552969965059
# Ratio of positive labels: 0.5381797886071092 | FPR: 0.08099905815048662
# Ratio of positive labels: 0.5385225457178653 | FPR: 0.08219445753497086
# Ratio of positive labels: 0.5389938750696015 | FPR: 0.08321496346632425
# Ratio of positive labels: 0.5394096695542747 | FPR: 0.08421253693778721
# Ratio of positive labels: 0.5398606682147976 | FPR: 0.08529905223275297
# Ratio of positive labels: 0.5402687882550741 | FPR: 0.08627377721123944
# Ratio of positive labels: 0.5407876001347811 | FPR: 0.08722731274660057
# Ratio of positive labels: 0.5416500897839808 | FPR: 0.08838614638552274
# Ratio of positive labels: 0.5419304049956916 | FPR: 0.08936075148136723
# Ratio of positive labels: 0.5423942905864149 | FPR: 0.09020957674129745
# Ratio of positive labels: 0.5427860126457016 | FPR: 0.09100946865136822
# Ratio of positive labels: 0.5433346047978886 | FPR: 0.09230832671828125
# Ratio of positive labels: 0.5439230211936613 | FPR: 0.0932949663778941
# Ratio of positive labels: 0.544661165038737 | FPR: 0.09425157321643216
# Ratio of positive labels: 0.5450745492545075 | FPR: 0.09508904910950891
# Ratio of positive labels: 0.5457569727032405 | FPR: 0.095939644161939
# Ratio of positive labels: 0.5459456279840393 | FPR: 0.09701865667983647
# Ratio of positive labels: 0.5463442102503859 | FPR: 0.09796992262211046
# Ratio of positive labels: 0.5468312804684571 | FPR: 0.09915289276064654
# Ratio of positive labels: 0.5475471662174646 | FPR: 0.10004666622222645
# Ratio of positive labels: 0.5480986028433694 | FPR: 0.10100848105206554
# Ratio of positive labels: 0.5487425351164943 | FPR: 0.10200839244493042
# Ratio of positive labels: 0.5492726919195192 | FPR: 0.10289719539633892
# Ratio of positive labels: 0.5496279850643572 | FPR: 0.10369629636425354
# Ratio of positive labels: 0.5500949991363715 | FPR: 0.10438086926482487
# Ratio of positive labels: 0.5503463932757362 | FPR: 0.1053323843929334
# Ratio of positive labels: 0.550557584307283 | FPR: 0.10601691056329854
# Ratio of positive labels: 0.5509951239369563 | FPR: 0.10693710675126769
# Ratio of positive labels: 0.5513460408242032 | FPR: 0.10803414005140306
# Ratio of positive labels: 0.551873461969896 | FPR: 0.10894687872279371
# Ratio of positive labels: 0.5524262721873088 | FPR: 0.11004215480901026
# Ratio of positive labels: 0.5527901470927599 | FPR: 0.1110845206451227
# Ratio of positive labels: 0.5532241252192778 | FPR: 0.11185498427979423
# Ratio of positive labels: 0.5538020688901774 | FPR: 0.11296543726523306
# Ratio of positive labels: 0.5543703802468313 | FPR: 0.11413238223014809
# Ratio of positive labels: 0.5549045049214469 | FPR: 0.11500731398914059
# Ratio of positive labels: 0.5554298735256269 | FPR: 0.11583511610560569
# Ratio of positive labels: 0.5559710896659377 | FPR: 0.11666571816489296
# Ratio of positive labels: 0.5563664809154765 | FPR: 0.11737002120950638
# Ratio of positive labels: 0.5568115455076359 | FPR: 0.11831905344757242
# Ratio of positive labels: 0.5573209736430663 | FPR: 0.11909429290243728
# Ratio of positive labels: 0.5577593877213565 | FPR: 0.12015653420051811
# Ratio of positive labels: 0.5584096999242193 | FPR: 0.12110061640143437
# Ratio of positive labels: 0.559011170456043 | FPR: 0.12244091131076504
# Ratio of positive labels: 0.5595110806839947 | FPR: 0.12349905000730764
# Ratio of positive labels: 0.560072060518622 | FPR: 0.12461736933305853
# Ratio of positive labels: 0.5606472678237286 | FPR: 0.12537783804668146
# Ratio of positive labels: 0.5610408944293652 | FPR: 0.12634491469988948
# Ratio of positive labels: 0.5616375997194051 | FPR: 0.12734233326616964
# Ratio of positive labels: 0.5620032444204117 | FPR: 0.12810275479440894
# Ratio of positive labels: 0.5625914515334446 | FPR: 0.1291314034455629
# Ratio of positive labels: 0.5630396858417092 | FPR: 0.1302545236896081
# Ratio of positive labels: 0.5636408431822958 | FPR: 0.13094832646140245
# Ratio of positive labels: 0.5642045740678124 | FPR: 0.13202782713793426
# Ratio of positive labels: 0.5646816808451368 | FPR: 0.13302762123127693
# Ratio of positive labels: 0.5654215218331785 | FPR: 0.13426855128687032
# Ratio of positive labels: 0.5659748875007923 | FPR: 0.13506947134175112
# Ratio of positive labels: 0.5663666687645541 | FPR: 0.13618785882616205
# Ratio of positive labels: 0.566662731508809 | FPR: 0.13724210248539942
# Ratio of positive labels: 0.5673202253777561 | FPR: 0.13813697836566644
# Ratio of positive labels: 0.5678385764481065 | FPR: 0.13895795234279218
# Ratio of positive labels: 0.5682818484227998 | FPR: 0.14006027169883198
# Ratio of positive labels: 0.5686988601428369 | FPR: 0.14089769663718488
# Ratio of positive labels: 0.5693250380869928 | FPR: 0.14174401514083798
# Ratio of positive labels: 0.5699828667808882 | FPR: 0.1429657135619096
# Ratio of positive labels: 0.5704465533340839 | FPR: 0.14401891378202794
# Ratio of positive labels: 0.5707791396109236 | FPR: 0.14467010085459964
# Ratio of positive labels: 0.5713034555329704 | FPR: 0.14541081430840322
# Ratio of positive labels: 0.5717105733079655 | FPR: 0.14612892124077118
# Ratio of positive labels: 0.5721253411268314 | FPR: 0.14692808433493978
# Ratio of positive labels: 0.5726758161806655 | FPR: 0.1478259754745162
# Ratio of positive labels: 0.5731428462239094 | FPR: 0.14880796937599122
# Ratio of positive labels: 0.5736925715660027 | FPR: 0.1497269004626553
# Ratio of positive labels: 0.5740592826460211 | FPR: 0.15082924006767254
# Ratio of positive labels: 0.5745901588115074 | FPR: 0.15181155117780515
# Ratio of positive labels: 0.5750336954428854 | FPR: 0.15264501462723834
# Ratio of positive labels: 0.5755705211696224 | FPR: 0.15338176924833796
# Ratio of positive labels: 0.5759780614842853 | FPR: 0.15404199974233287
# Ratio of positive labels: 0.5765452649678965 | FPR: 0.15509051774074548
# Ratio of positive labels: 0.5769965030514966 | FPR: 0.15628390130968903
# Ratio of positive labels: 0.5775567617062548 | FPR: 0.1570894151240053
# Ratio of positive labels: 0.5780923467524146 | FPR: 0.15797510194549733
# Ratio of positive labels: 0.5785679847143766 | FPR: 0.15910024345093185
# Ratio of positive labels: 0.5789374027372619 | FPR: 0.15997538476103693
# Ratio of positive labels: 0.5794377680131293 | FPR: 0.160875524261622
# Ratio of positive labels: 0.5797802352033029 | FPR: 0.16178267963345244
# Ratio of positive labels: 0.5802466264731019 | FPR: 0.16267928674833285
# Ratio of positive labels: 0.5806671637736198 | FPR: 0.16362333165704243
# Ratio of positive labels: 0.5811920621145855 | FPR: 0.16450480169654197
# Ratio of positive labels: 0.5817738184353233 | FPR: 0.16545619739315776
# Ratio of positive labels: 0.582275100709655 | FPR: 0.1661581468287112
# Ratio of positive labels: 0.5827424703815233 | FPR: 0.16712899927119057
# Ratio of positive labels: 0.5831764990084325 | FPR: 0.1678810793197791
# Ratio of positive labels: 0.5836168513025067 | FPR: 0.16871414126178066
# Ratio of positive labels: 0.5840800884439531 | FPR: 0.16950461386325633
# Ratio of positive labels: 0.5845934552847775 | FPR: 0.1702532030209778
# Ratio of positive labels: 0.5848429404234042 | FPR: 0.17091114883984154
# Ratio of positive labels: 0.585291883650909 | FPR: 0.17180780432893808
# Ratio of positive labels: 0.5856326867788763 | FPR: 0.172569714295031
# Ratio of positive labels: 0.5861157507256718 | FPR: 0.17362068313144252
# Ratio of positive labels: 0.5864323310089731 | FPR: 0.1745098144633631
# Ratio of positive labels: 0.5867776108149154 | FPR: 0.17526644242544157
# Ratio of positive labels: 0.5872255998638305 | FPR: 0.1760948080063404
# Ratio of positive labels: 0.5877111761313433 | FPR: 0.17710488304294686
# Ratio of positive labels: 0.5881495360550734 | FPR: 0.17797801064204924
# Ratio of positive labels: 0.5886723106161748 | FPR: 0.17880011099418328
# Ratio of positive labels: 0.589220889474534 | FPR: 0.17993656283040194
# Ratio of positive labels: 0.5897067890839944 | FPR: 0.1809265236967684
# Ratio of positive labels: 0.5902907716970531 | FPR: 0.1820402987613466
# Ratio of positive labels: 0.5906790221588607 | FPR: 0.18274778078061138
# Ratio of positive labels: 0.5912163713450441 | FPR: 0.18386130683006718
# Ratio of positive labels: 0.591809178633611 | FPR: 0.18478078791478217
# Ratio of positive labels: 0.592365695122752 | FPR: 0.18572633471548122
# Ratio of positive labels: 0.5928965181079492 | FPR: 0.18673775508665785
# Ratio of positive labels: 0.5933570332148339 | FPR: 0.18745406272968634
# Ratio of positive labels: 0.5939174431968001 | FPR: 0.18862592723419286
# Ratio of positive labels: 0.5944376512987559 | FPR: 0.1894693590625789
# Ratio of positive labels: 0.5947704691109896 | FPR: 0.19053108112767916
# Ratio of positive labels: 0.5951098278930005 | FPR: 0.191513767089377
# Ratio of positive labels: 0.5956117287232745 | FPR: 0.19237467134306663
# Ratio of positive labels: 0.5961961349702186 | FPR: 0.19354274979247674
# Ratio of positive labels: 0.5966251370766325 | FPR: 0.1944241815256931
# Ratio of positive labels: 0.5970932832053693 | FPR: 0.19524425363339598
# Ratio of positive labels: 0.5975425954899737 | FPR: 0.19611389419189382
# Ratio of positive labels: 0.5979971523945125 | FPR: 0.19699430002714272
# Ratio of positive labels: 0.5984047468969341 | FPR: 0.19784740356680774
# Ratio of positive labels: 0.5989122692817487 | FPR: 0.19907453266729874
# Ratio of positive labels: 0.5993915521523373 | FPR: 0.19988638550992718
# Ratio of positive labels: 0.600011214900865 | FPR: 0.20093831337236742
# Ratio of positive labels: 0.6004716257133688 | FPR: 0.20182231710550183
# Ratio of positive labels: 0.6008490701431938 | FPR: 0.2024296183813964
# Ratio of positive labels: 0.6012046027437662 | FPR: 0.2033216436790614
# Ratio of positive labels: 0.601602744941537 | FPR: 0.2042100724308604
# Ratio of positive labels: 0.6020474792352546 | FPR: 0.20548307998593612
# Ratio of positive labels: 0.6025881700537725 | FPR: 0.20657633374393752
# Ratio of positive labels: 0.603142067230465 | FPR: 0.20763254464911923
# Ratio of positive labels: 0.6036594429754821 | FPR: 0.2086567177625326
# Ratio of positive labels: 0.6041183671822099 | FPR: 0.20963583122945637
# Ratio of positive labels: 0.6047696215641895 | FPR: 0.2106999522323561
# Ratio of positive labels: 0.6052639766045484 | FPR: 0.21162572610788397
# Ratio of positive labels: 0.6058247529878187 | FPR: 0.21271144817943283
# Ratio of positive labels: 0.6063277254285223 | FPR: 0.21361579904934339
# Ratio of positive labels: 0.6066947074793532 | FPR: 0.21449028732330122
# Ratio of positive labels: 0.6070672180470827 | FPR: 0.21542700686896563
# Ratio of positive labels: 0.6075451845861539 | FPR: 0.21632949421959036
# Ratio of positive labels: 0.6079887100055844 | FPR: 0.21740165626988628
# Ratio of positive labels: 0.6085232391239693 | FPR: 0.21837836905875405
# Ratio of positive labels: 0.6088900906004695 | FPR: 0.2194067836618727
# Ratio of positive labels: 0.6093179088978252 | FPR: 0.22028538339579745
# Ratio of positive labels: 0.6099591065569934 | FPR: 0.2211777822222033
# Ratio of positive labels: 0.6104296168236575 | FPR: 0.22206261837873567
# Ratio of positive labels: 0.610891937164822 | FPR: 0.2229442069864684
# Ratio of positive labels: 0.6113881874445906 | FPR: 0.22368813576413543
# Ratio of positive labels: 0.6118300760247866 | FPR: 0.2245973866218133
# Ratio of positive labels: 0.6123474485522977 | FPR: 0.22554072691363786
# Ratio of positive labels: 0.6128605275496782 | FPR: 0.22650113485006287
# Ratio of positive labels: 0.613332176313321 | FPR: 0.22752385320721816
# Ratio of positive labels: 0.6137423302784762 | FPR: 0.22831593285624338
# Ratio of positive labels: 0.6142925643747361 | FPR: 0.22938840414588466
# Ratio of positive labels: 0.6148219803184477 | FPR: 0.2303908963636883
# Ratio of positive labels: 0.6153348970126138 | FPR: 0.23132426290950037
# Ratio of positive labels: 0.6158477091185866 | FPR: 0.2322824603948972
# Ratio of positive labels: 0.6163644501433462 | FPR: 0.2332974463812646
# Ratio of positive labels: 0.6168850727507118 | FPR: 0.23425207127682218
# Ratio of positive labels: 0.6173015307938768 | FPR: 0.23509105963576146
# Ratio of positive labels: 0.6178142716562882 | FPR: 0.23619029406257347
# Ratio of positive labels: 0.6182753243042687 | FPR: 0.23703477367153306
# Ratio of positive labels: 0.6187524950494266 | FPR: 0.23790815056066972
# Ratio of positive labels: 0.6192928374297739 | FPR: 0.2390069330435707
# Ratio of positive labels: 0.6198407065070333 | FPR: 0.24003435280645957
# Ratio of positive labels: 0.6203022644442795 | FPR: 0.240979527423721
# Ratio of positive labels: 0.620709647044175 | FPR: 0.24171501278205143
# Ratio of positive labels: 0.6212146464548587 | FPR: 0.2426385944240526
# Ratio of positive labels: 0.621727329238111 | FPR: 0.24358593210064827
# Ratio of positive labels: 0.6222014530713343 | FPR: 0.24452598259237465
# Ratio of positive labels: 0.622694932203325 | FPR: 0.2454205156302083
# Ratio of positive labels: 0.6231999114507196 | FPR: 0.24664409677825658
# Ratio of positive labels: 0.6236402142957631 | FPR: 0.2475846099444489
# Ratio of positive labels: 0.6240620300680679 | FPR: 0.2485066344445665
# Ratio of positive labels: 0.6245900958864307 | FPR: 0.24964434096475108
# Ratio of positive labels: 0.6250653193033109 | FPR: 0.2505404115022124
# Ratio of positive labels: 0.6254620769210603 | FPR: 0.25142976992595534
# Ratio of positive labels: 0.6259790075410167 | FPR: 0.2523609986529901
# Ratio of positive labels: 0.626417745658938 | FPR: 0.2531849323980208
# Ratio of positive labels: 0.6269161966066792 | FPR: 0.25411757734230617
# Ratio of positive labels: 0.6274257290563503 | FPR: 0.25494001867151783
# Ratio of positive labels: 0.6279241620435219 | FPR: 0.2558336182587564
# Ratio of positive labels: 0.6284445844520716 | FPR: 0.25680858311874316
# Ratio of positive labels: 0.6289794562793567 | FPR: 0.2577581833642943
# Ratio of positive labels: 0.6293286206231977 | FPR: 0.25859542328936985
# Ratio of positive labels: 0.629867283089554 | FPR: 0.2597671747566132
# Ratio of positive labels: 0.6303118039285057 | FPR: 0.26067775928606757
# Ratio of positive labels: 0.6307459325685879 | FPR: 0.26156021021507114
# Ratio of positive labels: 0.6312522177339867 | FPR: 0.26251160390106126
# Ratio of positive labels: 0.6317727436687726 | FPR: 0.2635133445951979
# Ratio of positive labels: 0.6321970384447031 | FPR: 0.2643656072398319
# Ratio of positive labels: 0.6326715153492364 | FPR: 0.2653713993922007
# Ratio of positive labels: 0.6331815081925506 | FPR: 0.2664831573033311
# Ratio of positive labels: 0.6337090362357879 | FPR: 0.26745328361519854
# Ratio of positive labels: 0.634169704667703 | FPR: 0.26844467212395745
# Ratio of positive labels: 0.634655123583484 | FPR: 0.2695270296257705
# Ratio of positive labels: 0.635144128417671 | FPR: 0.27037884885418517
# Ratio of positive labels: 0.6356158485560814 | FPR: 0.2715441960270971
# Ratio of positive labels: 0.636108525576036 | FPR: 0.27257345130293664
# Ratio of positive labels: 0.6365736669873552 | FPR: 0.27365422877852147
# Ratio of positive labels: 0.6370081202470095 | FPR: 0.2745179569829657
# Ratio of positive labels: 0.6374087759973425 | FPR: 0.2754065910733182
# Ratio of positive labels: 0.6379022597192501 | FPR: 0.27656902194873056
# Ratio of positive labels: 0.6383515702327544 | FPR: 0.27760449794388453
# Ratio of positive labels: 0.638818173497717 | FPR: 0.278534649035088
# Ratio of positive labels: 0.639342434653937 | FPR: 0.2793841912696241
# Ratio of positive labels: 0.6397756236510989 | FPR: 0.2802381136763849
# Ratio of positive labels: 0.6402495293639954 | FPR: 0.2811634860285704
# Ratio of positive labels: 0.6406500312707984 | FPR: 0.2820057458001813
# Ratio of positive labels: 0.6411045296515678 | FPR: 0.28294572351425495
# Ratio of positive labels: 0.6415261078866847 | FPR: 0.2838894222942781
# Ratio of positive labels: 0.6420111191684795 | FPR: 0.2848566726600243
# Ratio of positive labels: 0.6424929290662407 | FPR: 0.2858406407899644
# Ratio of positive labels: 0.6430143321896967 | FPR: 0.2868872141867954
# Ratio of positive labels: 0.6434733000875407 | FPR: 0.2877793843298874
# Ratio of positive labels: 0.643912928389123 | FPR: 0.2885186649716831
# Ratio of positive labels: 0.6443952951293318 | FPR: 0.28949091371037877
# Ratio of positive labels: 0.6450108928217766 | FPR: 0.2904958100785387
# Ratio of positive labels: 0.6454412768890716 | FPR: 0.2912676658004343
# Ratio of positive labels: 0.6459817871555253 | FPR: 0.2920958319489292
# Ratio of positive labels: 0.6463966353805937 | FPR: 0.2929186722872274
# Ratio of positive labels: 0.6468761318072699 | FPR: 0.2937939301476598
# Ratio of positive labels: 0.6473589541247472 | FPR: 0.2948680675141613
# Ratio of positive labels: 0.6478227776344662 | FPR: 0.29581434454030403
# Ratio of positive labels: 0.6483090529871334 | FPR: 0.29686254964269954
# Ratio of positive labels: 0.6488428834085969 | FPR: 0.29789146236879
# Ratio of positive labels: 0.649332336491052 | FPR: 0.29881293749861987
# Ratio of positive labels: 0.6498470130597074 | FPR: 0.2997820761569932
# Ratio of positive labels: 0.6503145758163767 | FPR: 0.30066990385610076
# Ratio of positive labels: 0.6507542163930737 | FPR: 0.301558432629898
# Ratio of positive labels: 0.6512191550805138 | FPR: 0.3024663474568615
# Ratio of positive labels: 0.6516563613156481 | FPR: 0.30337793982006267
# Ratio of positive labels: 0.6521218200562846 | FPR: 0.3043334231163371
# Ratio of positive labels: 0.6525165045786896 | FPR: 0.30505461402896905
# Ratio of positive labels: 0.6529887600345845 | FPR: 0.3059129048833696
# Ratio of positive labels: 0.6535348051079598 | FPR: 0.3068518194729464
# Ratio of positive labels: 0.653964360965257 | FPR: 0.307739120063853
# Ratio of positive labels: 0.6544553217825555 | FPR: 0.30868503449684603
# Ratio of positive labels: 0.6549189820091732 | FPR: 0.30943370992793334
# Ratio of positive labels: 0.6554283168838883 | FPR: 0.31041421086602766
# Ratio of positive labels: 0.6558983205488805 | FPR: 0.31130419545560284
# Ratio of positive labels: 0.6563383845229381 | FPR: 0.312185806669257
# Ratio of positive labels: 0.6567758054780616 | FPR: 0.3131131738343128
# Ratio of positive labels: 0.6571836611267631 | FPR: 0.314112831997509
# Ratio of positive labels: 0.6576428130065284 | FPR: 0.315222939633016
# Ratio of positive labels: 0.6581260174820909 | FPR: 0.3163502489575924
# Ratio of positive labels: 0.658579648131608 | FPR: 0.31726908822229016
# Ratio of positive labels: 0.6590483460108106 | FPR: 0.3181292363040346
# Ratio of positive labels: 0.6595703257512515 | FPR: 0.3191848991595895
# Ratio of positive labels: 0.6600951173673019 | FPR: 0.32028141093702667
# Ratio of positive labels: 0.6605669778094493 | FPR: 0.32120140410145426
# Ratio of positive labels: 0.6610448507460505 | FPR: 0.3220633857795737
# Ratio of positive labels: 0.6615286835898437 | FPR: 0.32289118690616064
# Ratio of positive labels: 0.6620591219211572 | FPR: 0.3239380118081052
# Ratio of positive labels: 0.6625459056640416 | FPR: 0.3249381885849606
# Ratio of positive labels: 0.6630443264614843 | FPR: 0.3259990578061913
# Ratio of positive labels: 0.6634707104590477 | FPR: 0.3269068388851905
# Ratio of positive labels: 0.6640268275091163 | FPR: 0.3278640003908035
# Ratio of positive labels: 0.6645253165463709 | FPR: 0.32876696628376423
# Ratio of positive labels: 0.6650038142748164 | FPR: 0.3296619152516707
# Ratio of positive labels: 0.6655080754755685 | FPR: 0.3306030467149666
# Ratio of positive labels: 0.6659526535435979 | FPR: 0.33147064923111014
# Ratio of positive labels: 0.6663720499375356 | FPR: 0.33224268486491537
# Ratio of positive labels: 0.6668483987333369 | FPR: 0.33321657283454004
# Ratio of positive labels: 0.6672882611598278 | FPR: 0.3340525801335771
# Ratio of positive labels: 0.6677958769778737 | FPR: 0.3350833284176168
# Ratio of positive labels: 0.6682558312161591 | FPR: 0.33595424102453497
# Ratio of positive labels: 0.6687383554794539 | FPR: 0.33689291370694496
# Ratio of positive labels: 0.6692154060852198 | FPR: 0.33775671934061463
# Ratio of positive labels: 0.6697092508076367 | FPR: 0.3386518370782303
# Ratio of positive labels: 0.6701726588014991 | FPR: 0.33955030595483116
# Ratio of positive labels: 0.6706666556169735 | FPR: 0.3404576230452402
# Ratio of positive labels: 0.67114140181432 | FPR: 0.34145911443770127
# Ratio of positive labels: 0.6716794734080401 | FPR: 0.342455103145321
# Ratio of positive labels: 0.6721515831463476 | FPR: 0.34339905918065977
# Ratio of positive labels: 0.6726211130570682 | FPR: 0.3441903164199005
# Ratio of positive labels: 0.6730826346522216 | FPR: 0.34503720698308726
# Ratio of positive labels: 0.6735796913595343 | FPR: 0.34599905978516365
# Ratio of positive labels: 0.6740035934861965 | FPR: 0.3469096289711952
# Ratio of positive labels: 0.6744684473825746 | FPR: 0.34780446539333676
# Ratio of positive labels: 0.6749523586189795 | FPR: 0.34883733467025696
# Ratio of positive labels: 0.6754363563538808 | FPR: 0.3496119634087005
# Ratio of positive labels: 0.6758802255221836 | FPR: 0.35060227720569115
# Ratio of positive labels: 0.676321721064917 | FPR: 0.351472322266518
# Ratio of positive labels: 0.6768115285025906 | FPR: 0.35246839341761754
# Ratio of positive labels: 0.6773279858298249 | FPR: 0.3533900175797405
# Ratio of positive labels: 0.6778151782090763 | FPR: 0.35440224296487277
# Ratio of positive labels: 0.678281274388163 | FPR: 0.35528477437890377
# Ratio of positive labels: 0.6787475494787613 | FPR: 0.356162648647365
# Ratio of positive labels: 0.6792324230725708 | FPR: 0.35708590240551996
# Ratio of positive labels: 0.6796911294196079 | FPR: 0.3579544410644592
# Ratio of positive labels: 0.680173612110963 | FPR: 0.3587477519692357
# Ratio of positive labels: 0.6806431314800745 | FPR: 0.3597405750898823
# Ratio of positive labels: 0.6810503097648183 | FPR: 0.3606735399126565
# Ratio of positive labels: 0.6815566712813733 | FPR: 0.3615730868231511
# Ratio of positive labels: 0.6820448651687431 | FPR: 0.36258973422348645
# Ratio of positive labels: 0.6825124482882473 | FPR: 0.36349776873961565
# Ratio of positive labels: 0.6829647346269726 | FPR: 0.3643985453645738
# Ratio of positive labels: 0.6834275490294369 | FPR: 0.36525098907200754
# Ratio of positive labels: 0.6838392722069944 | FPR: 0.3659247027571724
# Ratio of positive labels: 0.6843384032265902 | FPR: 0.3668404940140818
# Ratio of positive labels: 0.6847635592766345 | FPR: 0.36773630679513575
# Ratio of positive labels: 0.6851967297793136 | FPR: 0.3686682731087198
# Ratio of positive labels: 0.6856987672620121 | FPR: 0.3695345950898602
# Ratio of positive labels: 0.6861678831192832 | FPR: 0.37042437867245903
# Ratio of positive labels: 0.6866270539720859 | FPR: 0.3714182539943081
# Ratio of positive labels: 0.6871040627101695 | FPR: 0.37237185800539546
# Ratio of positive labels: 0.6875786744254412 | FPR: 0.37347896110813794
# Ratio of positive labels: 0.6880609321781148 | FPR: 0.3744902894980213
# Ratio of positive labels: 0.6885157787105533 | FPR: 0.37536406158984603
# Ratio of positive labels: 0.6889957880404288 | FPR: 0.37621103189268856
# Ratio of positive labels: 0.6894385834861108 | FPR: 0.37704881331140966
# Ratio of positive labels: 0.6899064766588668 | FPR: 0.3780809476899561
# Ratio of positive labels: 0.6903893802243064 | FPR: 0.3789198541587768
# Ratio of positive labels: 0.6908402695301987 | FPR: 0.37983363004041965
# Ratio of positive labels: 0.6912987899044584 | FPR: 0.3807059588523181
# Ratio of positive labels: 0.69172803015226 | FPR: 0.38154206009321845
# Ratio of positive labels: 0.6921796760302058 | FPR: 0.38250151347668265
# Ratio of positive labels: 0.6926560081760191 | FPR: 0.3833438060053643
# Ratio of positive labels: 0.6931251387191738 | FPR: 0.3841624776524935
# Ratio of positive labels: 0.6935262931233744 | FPR: 0.38496500008515794
# Ratio of positive labels: 0.6940104514309431 | FPR: 0.38580003446593575
# Ratio of positive labels: 0.6944559456272503 | FPR: 0.3867060854574202
# Ratio of positive labels: 0.6948727176987495 | FPR: 0.38743626223125066
# Ratio of positive labels: 0.6953091679297159 | FPR: 0.38826653429750774
# Ratio of positive labels: 0.6958108273778189 | FPR: 0.38927550654926313
# Ratio of positive labels: 0.6962789058059813 | FPR: 0.39018851273737953
# Ratio of positive labels: 0.696771060356315 | FPR: 0.39099427991799063
# Ratio of positive labels: 0.6972202930303268 | FPR: 0.39198713129562934
# Ratio of positive labels: 0.6977031007069031 | FPR: 0.39289668357932483
# Ratio of positive labels: 0.69816698772687 | FPR: 0.39376153500823036
# Ratio of positive labels: 0.6986357852232578 | FPR: 0.3945511977459769
# Ratio of positive labels: 0.6990976380670495 | FPR: 0.3954245971049714
# Ratio of positive labels: 0.6995337275147936 | FPR: 0.39630331060539953
# Ratio of positive labels: 0.7000430587222147 | FPR: 0.39723200651292584
# Ratio of positive labels: 0.7004960082253328 | FPR: 0.39813052082037365
# Ratio of positive labels: 0.7009632295943101 | FPR: 0.399092742171564
# Ratio of positive labels: 0.7014703236674681 | FPR: 0.40008084093261465
# Ratio of positive labels: 0.7019517437022291 | FPR: 0.401045685208193
# Ratio of positive labels: 0.7024030176674008 | FPR: 0.40200836742240137
# Ratio of positive labels: 0.7028753993610224 | FPR: 0.40294338064180824
# Ratio of positive labels: 0.7033386496790517 | FPR: 0.40396665748458915
# Ratio of positive labels: 0.7037974508142013 | FPR: 0.4049113050547227
# Ratio of positive labels: 0.7042933080799353 | FPR: 0.40588155326831044
# Ratio of positive labels: 0.7047340121057193 | FPR: 0.4067300994710357
# Ratio of positive labels: 0.7052231531579056 | FPR: 0.40761603757789544
# Ratio of positive labels: 0.7056963256376988 | FPR: 0.4085002093816719
# Ratio of positive labels: 0.7061467896192017 | FPR: 0.4094077410782167
# Ratio of positive labels: 0.7066202582682044 | FPR: 0.4102086327821577
# Ratio of positive labels: 0.7070915747918755 | FPR: 0.4111922472903471
# Ratio of positive labels: 0.7075516835562731 | FPR: 0.41206029011272083
# Ratio of positive labels: 0.7080255474535125 | FPR: 0.41301490268121566
# Ratio of positive labels: 0.7085175879964154 | FPR: 0.41394263218367455
# Ratio of positive labels: 0.7089511059659775 | FPR: 0.414798615318434
# Ratio of positive labels: 0.7093894171024335 | FPR: 0.41569794225181517
# Ratio of positive labels: 0.7098818164084834 | FPR: 0.4165663305687655
# Ratio of positive labels: 0.7103451670130492 | FPR: 0.41759861834761
# Ratio of positive labels: 0.710817609782121 | FPR: 0.4184477266791815
# Ratio of positive labels: 0.7112879481337459 | FPR: 0.41931755163128814
# Ratio of positive labels: 0.7117628627491939 | FPR: 0.42015017744405014
# Ratio of positive labels: 0.7121824563581899 | FPR: 0.4210145875508037
# Ratio of positive labels: 0.7126643525124945 | FPR: 0.42191057099431195
# Ratio of positive labels: 0.7131132160856157 | FPR: 0.4228577861859025
# Ratio of positive labels: 0.7135799260354052 | FPR: 0.42380963918581677
# Ratio of positive labels: 0.7140357933279268 | FPR: 0.4248188465519856
# Ratio of positive labels: 0.7145028190727651 | FPR: 0.4256174876809481
# Ratio of positive labels: 0.7149853063778854 | FPR: 0.4265811234548721
# Ratio of positive labels: 0.7154678701574887 | FPR: 0.4273265778895679
# Ratio of positive labels: 0.7159352594003063 | FPR: 0.42819296689985425
# Ratio of positive labels: 0.7164201816952572 | FPR: 0.42909471935930577
# Ratio of positive labels: 0.7168661239346552 | FPR: 0.42996219097138616
# Ratio of positive labels: 0.7173620836318536 | FPR: 0.4308778552427376
# Ratio of positive labels: 0.7178148643307466 | FPR: 0.43186299813607315
# Ratio of positive labels: 0.7182807795672854 | FPR: 0.4327081191635363
# Ratio of positive labels: 0.7187210350085269 | FPR: 0.43353240100558926
# Ratio of positive labels: 0.7192044652264695 | FPR: 0.4344175227091787
# Ratio of positive labels: 0.7196558465613564 | FPR: 0.4353652347639513
# Ratio of positive labels: 0.7201437603765803 | FPR: 0.43628539255258003
# Ratio of positive labels: 0.720612536007386 | FPR: 0.43718030451960654
# Ratio of positive labels: 0.7210771891974698 | FPR: 0.43824800372765166
# Ratio of positive labels: 0.7215441156175889 | FPR: 0.4391731652374411
# Ratio of positive labels: 0.7219709280276948 | FPR: 0.440052033788064
# Ratio of positive labels: 0.7224403331071182 | FPR: 0.44085107642478555
# Ratio of positive labels: 0.7229394030814281 | FPR: 0.4418471690987994
# Ratio of positive labels: 0.7233984770558378 | FPR: 0.4427653836518239
# Ratio of positive labels: 0.7238703280035126 | FPR: 0.44381629450358295
# Ratio of positive labels: 0.7243381041129893 | FPR: 0.44472653097163317
# Ratio of positive labels: 0.724795554821015 | FPR: 0.4456392350643618
# Ratio of positive labels: 0.7252490078308813 | FPR: 0.44651472543898657
# Ratio of positive labels: 0.7257026547861358 | FPR: 0.4473428180357958
# Ratio of positive labels: 0.7261689684636831 | FPR: 0.44825894332860017
# Ratio of positive labels: 0.7266208991267653 | FPR: 0.4491525951190973
# Ratio of positive labels: 0.727102014281544 | FPR: 0.4501439955610858
# Ratio of positive labels: 0.7275749430269772 | FPR: 0.45107758041822227
# Ratio of positive labels: 0.7280273648920311 | FPR: 0.4520403050715359
# Ratio of positive labels: 0.7284840977693462 | FPR: 0.4530175863835671
# Ratio of positive labels: 0.7289574354056768 | FPR: 0.45381631659893923
# Ratio of positive labels: 0.7294165380808646 | FPR: 0.45475316648941294
# Ratio of positive labels: 0.729861493125781 | FPR: 0.4556289250942227
# Ratio of positive labels: 0.7303087136556864 | FPR: 0.4565174356787027
# Ratio of positive labels: 0.730760222484272 | FPR: 0.45745120682035273
# Ratio of positive labels: 0.7312403836577568 | FPR: 0.45847467789699614
# Ratio of positive labels: 0.7317023697720695 | FPR: 0.45926884529645984
# Ratio of positive labels: 0.7321645097884417 | FPR: 0.460106356060008
# Ratio of positive labels: 0.7326348835658918 | FPR: 0.4610051292825671
# Ratio of positive labels: 0.7331053768036758 | FPR: 0.4619607621758827
# Ratio of positive labels: 0.7335659284387758 | FPR: 0.46292059774527616
# Ratio of positive labels: 0.7340045501916663 | FPR: 0.46377416912817443
# Ratio of positive labels: 0.7344474259570622 | FPR: 0.46469646353414124
# Ratio of positive labels: 0.7349185301629396 | FPR: 0.4656550686898626
# Ratio of positive labels: 0.7353618056650586 | FPR: 0.46645815078213415
# Ratio of positive labels: 0.7358212433839774 | FPR: 0.4674512600572509
# Ratio of positive labels: 0.7362927707897201 | FPR: 0.4682257092928245
# Ratio of positive labels: 0.7367445699512502 | FPR: 0.4691141485830385
# Ratio of positive labels: 0.7372183421418967 | FPR: 0.4700366929966475
# Ratio of positive labels: 0.7376902417188899 | FPR: 0.47099511661044147
# Ratio of positive labels: 0.7381504178492745 | FPR: 0.4718925603697034
# Ratio of positive labels: 0.7386127192663007 | FPR: 0.47289867539630825
# Ratio of positive labels: 0.7390692749130159 | FPR: 0.47375938357684955
# Ratio of positive labels: 0.7395260009294099 | FPR: 0.4745755400479607
# Ratio of positive labels: 0.739977025485273 | FPR: 0.4754100285518032
# Ratio of positive labels: 0.7404419131993882 | FPR: 0.47637016333952475
# Ratio of positive labels: 0.7409088871171791 | FPR: 0.4772485823614379
# Ratio of positive labels: 0.7413896081914237 | FPR: 0.478106073723592
# Ratio of positive labels: 0.7418665206475327 | FPR: 0.47899324467331134
# Ratio of positive labels: 0.7423105769174866 | FPR: 0.47990992265518867
# Ratio of positive labels: 0.7427703234616567 | FPR: 0.48088881839686964
# Ratio of positive labels: 0.7432398779152936 | FPR: 0.4818156721705171
# Ratio of positive labels: 0.7436902819069713 | FPR: 0.48275629526725383
# Ratio of positive labels: 0.7441427997253851 | FPR: 0.4836894544433568
# Ratio of positive labels: 0.744603177345149 | FPR: 0.4845864019454857
# Ratio of positive labels: 0.7450656224796505 | FPR: 0.485525889797146
# Ratio of positive labels: 0.7455396834805287 | FPR: 0.4864942896858706
# Ratio of positive labels: 0.7460100266984223 | FPR: 0.48738074927337927
# Ratio of positive labels: 0.7464785781360417 | FPR: 0.48829811752739516
# Ratio of positive labels: 0.7469434468755762 | FPR: 0.48923861361480303
# Ratio of positive labels: 0.7474084489403245 | FPR: 0.49009963927962186
# Ratio of positive labels: 0.7478660078295306 | FPR: 0.4910577820875339
# Ratio of positive labels: 0.7483275078875087 | FPR: 0.4920104120786161
# Ratio of positive labels: 0.7487834928613343 | FPR: 0.4928990700017547
# Ratio of positive labels: 0.7492415268521152 | FPR: 0.4938069796478726
# Ratio of positive labels: 0.7497128764795555 | FPR: 0.49472463397625194
# Ratio of positive labels: 0.7501787051056189 | FPR: 0.49561820709529625
# Ratio of positive labels: 0.7506371710914399 | FPR: 0.496577721764566
# Ratio of positive labels: 0.7510995306550828 | FPR: 0.49741963099134395
# Ratio of positive labels: 0.7515620306678532 | FPR: 0.49840018955188514
# Ratio of positive labels: 0.7520190837633449 | FPR: 0.49875512336103656
# Ratio of positive labels: 0.7524781552450646 | FPR: 0.4987723071146708
# Ratio of positive labels: 0.7529373785948449 | FPR: 0.498830243357619
# Ratio of positive labels: 0.753393049272131 | FPR: 0.49885648359910445
# Ratio of positive labels: 0.7538488838283108 | FPR: 0.49889186896142523
# Ratio of positive labels: 0.7543011913262153 | FPR: 0.4988828433895878
# Ratio of positive labels: 0.7547536744867873 | FPR: 0.49887385106104776
# Ratio of positive labels: 0.7552044941093858 | FPR: 0.49892922990950384
# Ratio of positive labels: 0.7556536593510838 | FPR: 0.49896422208399616
# Ratio of positive labels: 0.7560993478033923 | FPR: 0.4989587931157635
# Ratio of positive labels: 0.7565434066848141 | FPR: 0.4989552121476926
# Ratio of positive labels: 0.7569858449163414 | FPR: 0.49894069536369456
# Ratio of positive labels: 0.7574284928442754 | FPR: 0.49894080338651475
# Ratio of positive labels: 0.7578658947892822 | FPR: 0.498939092838013
# Ratio of positive labels: 0.7582998941925695 | FPR: 0.4988956462873933
# Ratio of positive labels: 0.7587323211370994 | FPR: 0.4989211976065261
# Ratio of positive labels: 0.759168609098356 | FPR: 0.4989358066260278
# Ratio of positive labels: 0.7596033220156643 | FPR: 0.49889982148046663
# Ratio of positive labels: 0.760032864805649 | FPR: 0.4989216235646422
# Ratio of positive labels: 0.7604626610383795 | FPR: 0.4989001818342053
# Ratio of positive labels: 0.760890914019903 | FPR: 0.49889317972499153
# Ratio of positive labels: 0.7613194241587381 | FPR: 0.49887545004399636
# Ratio of positive labels: 0.7617464011692286 | FPR: 0.4988703061354094
# Ratio of positive labels: 0.7621718532645477 | FPR: 0.49887232344227955
# Ratio of positive labels: 0.7625940060712905 | FPR: 0.4989278093978442
# Ratio of positive labels: 0.7630146565575506 | FPR: 0.49893327591943787
# Ratio of positive labels: 0.7634355889243536 | FPR: 0.4989103038893359
# Ratio of positive labels: 0.7638550286258358 | FPR: 0.49892287425022297
# Ratio of positive labels: 0.764269443770896 | FPR: 0.49894247974782346
# Ratio of positive labels: 0.7646806277727425 | FPR: 0.4989266803415542
# Ratio of positive labels: 0.7650956523886201 | FPR: 0.498898591007776
# Ratio of positive labels: 0.7655092156527894 | FPR: 0.49891637514722686
# Ratio of positive labels: 0.765919567803923 | FPR: 0.49890070491967503
# Ratio of positive labels: 0.7663249713596993 | FPR: 0.4989535106078761
# Ratio of positive labels: 0.7667307062509523 | FPR: 0.49899212085442934
# Ratio of positive labels: 0.7671385189886032 | FPR: 0.49900786886736215
# Ratio of positive labels: 0.767543163100937 | FPR: 0.4990026195416762
# Ratio of positive labels: 0.7679463973059281 | FPR: 0.4990392002801389
# Ratio of positive labels: 0.7683482289596019 | FPR: 0.49909304505557384
# Ratio of positive labels: 0.7687486653669005 | FPR: 0.4991137168164639
# Ratio of positive labels: 0.7691494468813745 | FPR: 0.4991516479174213
# Ratio of positive labels: 0.7695488416110007 | FPR: 0.4991634962569269
# Ratio of positive labels: 0.7699416754029785 | FPR: 0.4991355800767183
# Ratio of positive labels: 0.770336602867926 | FPR: 0.4991250015086181
# Ratio of positive labels: 0.7707301708602912 | FPR: 0.49910413235089096
# Ratio of positive labels: 0.7711241045977584 | FPR: 0.49916065436313684
# Ratio of positive labels: 0.7715166869353569 | FPR: 0.4991260735401826
# Ratio of positive labels: 0.7719045001635271 | FPR: 0.4991446932453883
# Ratio of positive labels: 0.7722926969355608 | FPR: 0.4991478647045048
# Ratio of positive labels: 0.772677862324467 | FPR: 0.49913225404052214
# Ratio of positive labels: 0.7730651225466396 | FPR: 0.4991252144374541
# Ratio of positive labels: 0.7734493648820325 | FPR: 0.4991301035202321
# Ratio of positive labels: 0.7738306047018596 | FPR: 0.4991774207514079
# Ratio of positive labels: 0.7742105521855047 | FPR: 0.4991432217911495
# Ratio of positive labels: 0.7745925979820677 | FPR: 0.4991328271864176
# Ratio of positive labels: 0.7749716638992163 | FPR: 0.499135981189221
# Ratio of positive labels: 0.7753477650122007 | FPR: 0.49915430159476964
# Ratio of positive labels: 0.7757259667913017 | FPR: 0.49912373884892447
# Ratio of positive labels: 0.776102897306055 | FPR: 0.4991285728931548
# Ratio of positive labels: 0.7764785629554313 | FPR: 0.4991350685653212
# Ratio of positive labels: 0.7768529700955275 | FPR: 0.4990996664997211
# Ratio of positive labels: 0.7772244528019184 | FPR: 0.4990994998336123
# Ratio of positive labels: 0.7775963646137486 | FPR: 0.49906761424438356
# Ratio of positive labels: 0.7779670367216055 | FPR: 0.4990858348569419
# Ratio of positive labels: 0.7783348114229427 | FPR: 0.49912562541493277
# Ratio of positive labels: 0.778701364283448 | FPR: 0.4992051508220086
# Ratio of positive labels: 0.7790650430098789 | FPR: 0.4992081273497059
# Ratio of positive labels: 0.7794308287569061 | FPR: 0.49919950463658175
# Ratio of positive labels: 0.7797954052968508 | FPR: 0.49924710868246497
# Ratio of positive labels: 0.7801571284535834 | FPR: 0.4992879549703713
# Ratio of positive labels: 0.7805193072169568 | FPR: 0.4992907754682447
# Ratio of positive labels: 0.7808802946047786 | FPR: 0.4992968761564537
# Ratio of positive labels: 0.7812400964858842 | FPR: 0.49925533784016773
# Ratio of positive labels: 0.7815970793490502 | FPR: 0.4992319684721828
# Ratio of positive labels: 0.7819545303526508 | FPR: 0.49926268533112056
# Ratio of positive labels: 0.7823108132176254 | FPR: 0.4992802299342648
# Ratio of positive labels: 0.7826643023420843 | FPR: 0.4992422524596208
# Ratio of positive labels: 0.7830182686998881 | FPR: 0.4992483725596538
# Ratio of positive labels: 0.7833694579358408 | FPR: 0.49927073289311724
# Ratio of positive labels: 0.7837211303228404 | FPR: 0.4992735401403569
# Ratio of positive labels: 0.7840700420258638 | FPR: 0.49925688937295076
# Ratio of positive labels: 0.7844194426869859 | FPR: 0.4992678005375396
# Ratio of positive labels: 0.7847677144301867 | FPR: 0.4992431353099591
# Ratio of positive labels: 0.7851148627179634 | FPR: 0.49927500116935297
# Ratio of positive labels: 0.785459282674263 | FPR: 0.49930354379461545
# Ratio of positive labels: 0.7858009874582195 | FPR: 0.4993384255009236
# Ratio of positive labels: 0.7861448055460585 | FPR: 0.4993073847393503
# Ratio of positive labels: 0.7864859190930784 | FPR: 0.4993181100671313
# Ratio of positive labels: 0.7868227410836143 | FPR: 0.49936080102271835
# Ratio of positive labels: 0.7871632792918861 | FPR: 0.4993873811703176
# Ratio of positive labels: 0.787501136361824 | FPR: 0.49938516844470743
# Ratio of positive labels: 0.7878395098096977 | FPR: 0.49941640220318123
# Ratio of positive labels: 0.7881768073500678 | FPR: 0.49946343487530226
# Ratio of positive labels: 0.788513034106295 | FPR: 0.49949285794784454
# Ratio of positive labels: 0.7888481951692629 | FPR: 0.4995095094936458
# Ratio of positive labels: 0.7891822955976335 | FPR: 0.4995166146889008
# Ratio of positive labels: 0.7895153404181036 | FPR: 0.49951579855324085
# Ratio of positive labels: 0.7898457573410768 | FPR: 0.4995465306837055
# Ratio of positive labels: 0.7901751335824668 | FPR: 0.4996070872329335
# Ratio of positive labels: 0.7905050463757133 | FPR: 0.4996360068616244
# Ratio of positive labels: 0.79083392333764 | FPR: 0.4996632658347475
# Ratio of positive labels: 0.7911570671519323 | FPR: 0.4996684958174047
# Ratio of positive labels: 0.7914838943914015 | FPR: 0.49965493011748024
# Ratio of positive labels: 0.7918097002973433 | FPR: 0.49964296930786045
# Ratio of positive labels: 0.7921344896497822 | FPR: 0.49962792569746384
# Ratio of positive labels: 0.7924567095689882 | FPR: 0.4996144865817966
# Ratio of positive labels: 0.7927779272505019 | FPR: 0.499621306965308
# Ratio of positive labels: 0.7930981473631252 | FPR: 0.4995815223889404
# Ratio of positive labels: 0.7934189249318994 | FPR: 0.4995589154125342
# Ratio of positive labels: 0.793737161397583 | FPR: 0.4995332824562191
# Ratio of positive labels: 0.7940544141353723 | FPR: 0.49954945973808385
# Ratio of positive labels: 0.794370687699556 | FPR: 0.49953780935523245
# Ratio of positive labels: 0.7946859866163535 | FPR: 0.49953698068261837
# Ratio of positive labels: 0.7950018538433018 | FPR: 0.4995515391514782
# Ratio of positive labels: 0.7953167506655135 | FPR: 0.4995230422073084
# Ratio of positive labels: 0.7956291478080555 | FPR: 0.4995253074765223
# Ratio of positive labels: 0.7959421195373361 | FPR: 0.4995015321569186
# Ratio of positive labels: 0.7962526051183408 | FPR: 0.49946253904810545
# Ratio of positive labels: 0.7965606159379909 | FPR: 0.49945572602179233
# Ratio of positive labels: 0.7968707364775358 | FPR: 0.4994535069306297
# Ratio of positive labels: 0.797179912968169 | FPR: 0.4994345518499972
# Ratio of positive labels: 0.7974881497140582 | FPR: 0.49946276677391066
# Ratio of positive labels: 0.7977954509932459 | FPR: 0.4994408202718964
# Ratio of positive labels: 0.7981018210578469 | FPR: 0.49944318266184445
# Ratio of positive labels: 0.7984072641342449 | FPR: 0.49947125647313695
# Ratio of positive labels: 0.79871027385155 | FPR: 0.49949471375420884
# Ratio of positive labels: 0.7990138778071224 | FPR: 0.4994924592873917
# Ratio of positive labels: 0.7993165672943263 | FPR: 0.4994555731090766
# Ratio of positive labels: 0.7996183464385768 | FPR: 0.4994819556662321
# Ratio of positive labels: 0.7999192193405115 | FPR: 0.49948873950639716
# Ratio of positive labels: 0.8002176908280497 | FPR: 0.4994820097720993
# Ratio of positive labels: 0.8005152686897176 | FPR: 0.49948428220915836
# Ratio of positive labels: 0.8008104621667232 | FPR: 0.49949252691700013
# Ratio of positive labels: 0.8011047744704859 | FPR: 0.49950373208398197
# Ratio of positive labels: 0.8014011901621607 | FPR: 0.4995432197567515
# Ratio of positive labels: 0.8016937474795425 | FPR: 0.4995840779998839
# Ratio of positive labels: 0.8019884071494693 | FPR: 0.499593611302212
# Ratio of positive labels: 0.8022821924596552 | FPR: 0.4995853121879641
# Ratio of positive labels: 0.8025736258168507 | FPR: 0.49959629689437496
# Ratio of positive labels: 0.8028656762342068 | FPR: 0.4996116869649601
# Ratio of positive labels: 0.8031553867719545 | FPR: 0.49962260026203803
# Ratio of positive labels: 0.8034442427076066 | FPR: 0.4996010330368244
# Ratio of positive labels: 0.8037337205688946 | FPR: 0.49963254840567245
# Ratio of positive labels: 0.8040208764398876 | FPR: 0.49965514756595947
# ...
# Ratio of positive labels: 0.8304073404486763 | FPR: 0.49966094190719856
# Ratio of positive labels: 0.8306228327537067 | FPR: 0.4996728085478926
# Ratio of positive labels: 0.8308365090907245 | FPR: 0.49969479734162775
# Ratio of positive labels: 0.8310509112155752 | FPR: 0.49973447435427837
# Ratio of positive labels: 0.8312647705509234 | FPR: 0.4997297471775352
# Ratio of positive labels: 0.8314780891553867 | FPR: 0.49972882461589807
# Ratio of positive labels: 0.8316883438278487 | FPR: 0.4997228538852855
# Ratio of positive labels: 0.8318993292568357 | FPR: 0.4997168982132431
# Ratio of positive labels: 0.8321085237927912 | FPR: 0.499709698098617
# Ratio of positive labels: 0.8323197077739525 | FPR: 0.499693711077093
# Ratio of positive labels: 0.8325303611427624 | FPR: 0.4996966084213462
# Ratio of positive labels: 0.8327404858965045 | FPR: 0.49969573438427306
# Ratio of positive labels: 0.8329500840224511 | FPR: 0.4996748124375784
# Ratio of positive labels: 0.833155402809258 | FPR: 0.49968898662204425
# Ratio of positive labels: 0.8333639582950522 | FPR: 0.49967062541171825
# Ratio of positive labels: 0.8335707446058119 | FPR: 0.4996747819291112
# Ratio of positive labels: 0.8337782621218677 | FPR: 0.49967144679370723
# Ratio of positive labels: 0.8339840174545237 | FPR: 0.4996606479942117
# Ratio of positive labels: 0.8341905047381782 | FPR: 0.49966853275058115
# Ratio of positive labels: 0.8343952367761034 | FPR: 0.4996602488692561
# Ratio of positive labels: 0.8346007014879634 | FPR: 0.49968672495443556
# Ratio of positive labels: 0.8348044178383918 | FPR: 0.49972304867032386
# Ratio of positive labels: 0.8350088675632827 | FPR: 0.49974938149829023
# Ratio of positive labels: 0.8352128118506652 | FPR: 0.4997435108238432
# Ratio of positive labels: 0.8354162525725277 | FPR: 0.499741358344002
# Ratio of positive labels: 0.8356191915916257 | FPR: 0.49971701637852484
# Ratio of positive labels: 0.8358216307615385 | FPR: 0.4996853452150921
# Ratio of positive labels: 0.8360235719267258 | FPR: 0.4996992623625309
# Ratio of positive labels: 0.8362250169225837 | FPR: 0.49967751882368694
# Ratio of positive labels: 0.8364259675754999 | FPR: 0.49969631939101916
# Ratio of positive labels: 0.8366264257029097 | FPR: 0.4997261032768342
# Ratio of positive labels: 0.8368263931133499 | FPR: 0.49972154256849133
# Ratio of positive labels: 0.837025871606514 | FPR: 0.4997084355642597
# Ratio of positive labels: 0.8372248629733052 | FPR: 0.49971611756273804
# Ratio of positive labels: 0.8374233689958914 | FPR: 0.499731097888905
# Ratio of positive labels: 0.837621391447757 | FPR: 0.499709500962849
# Ratio of positive labels: 0.8378189320937566 | FPR: 0.49971228745463814
# Ratio of positive labels: 0.8380159926901668 | FPR: 0.4996907658678422
# Ratio of positive labels: 0.8382125749847391 | FPR: 0.4997008498776094
# Ratio of positive labels: 0.8384074685970078 | FPR: 0.4996709094898067
# Ratio of positive labels: 0.8386031009647688 | FPR: 0.499679782469997
# Ratio of positive labels: 0.8387982602197579 | FPR: 0.4996850064268362
# Ratio of positive labels: 0.8389929480761497 | FPR: 0.4996382854610079
# Ratio of positive labels: 0.8391859599686852 | FPR: 0.4996338967021753
# Ratio of positive labels: 0.8393797115907089 | FPR: 0.49963915706125656
# Ratio of positive labels: 0.8395729969037342 | FPR: 0.4996299643442066
# Ratio of positive labels: 0.8397634137458969 | FPR: 0.49962079372500756
# Ratio of positive labels: 0.8399557743628159 | FPR: 0.49962725134783753
# Ratio of positive labels: 0.8401464746445149 | FPR: 0.49964688291740655
# Ratio of positive labels: 0.8403379157629751 | FPR: 0.4996497010183221
# Ratio of positive labels: 0.8405288988888769 | FPR: 0.4996561008898315
# Ratio of positive labels: 0.8407182309220658 | FPR: 0.49967801711109067
# Ratio of positive labels: 0.8409083044053647 | FPR: 0.4996640815464421
# Ratio of positive labels: 0.8410979247938918 | FPR: 0.4996644819255281
# Ratio of positive labels: 0.8412859032310676 | FPR: 0.4996958336954361
# Ratio of positive labels: 0.8414746236924807 | FPR: 0.49969381724873096
# Ratio of positive labels: 0.841662895887297 | FPR: 0.4997060573562264
# Ratio of positive labels: 0.8418507214107693 | FPR: 0.499672005134039
# Ratio of positive labels: 0.8420381018505902 | FPR: 0.4996676544222104
# Ratio of positive labels: 0.8422250387869363 | FPR: 0.4996786986050904
# Ratio of positive labels: 0.8424103517608135 | FPR: 0.49969562683732055
# Ratio of positive labels: 0.8425964077964488 | FPR: 0.49971369573353513
# Ratio of positive labels: 0.8427820250211969 | FPR: 0.49969634469770674
# Ratio of positive labels: 0.8429660271307101 | FPR: 0.4996896352301116
# Ratio of positive labels: 0.8431507727637968 | FPR: 0.4996994121183387
# Ratio of positive labels: 0.843335084212592 | FPR: 0.4996903646411696
# Ratio of positive labels: 0.843518963005912 | FPR: 0.4997142022133777
# Ratio of positive labels: 0.8437012383338355 | FPR: 0.4997473625470545
# Ratio of positive labels: 0.8438819158291384 | FPR: 0.49975585508682074
# Ratio of positive labels: 0.8440645098660703 | FPR: 0.4997573102253682
# Ratio of positive labels: 0.8442455090589848 | FPR: 0.4997797899768809
# Ratio of positive labels: 0.8444272527103236 | FPR: 0.49976137717458907
# Ratio of positive labels: 0.8446074072174741 | FPR: 0.4997803032863598
# Ratio of positive labels: 0.8447871422734083 | FPR: 0.49979336461773616
# Ratio of positive labels: 0.8449652965519807 | FPR: 0.49978895373377474
# Ratio of positive labels: 0.8451453598776308 | FPR: 0.4997775844627358
# Ratio of positive labels: 0.8453250054234276 | FPR: 0.4997581209302541
# Ratio of positive labels: 0.8455042346416748 | FPR: 0.4997352262627737
# Ratio of positive labels: 0.8456830489779525 | FPR: 0.49971238459214745
# Ratio of positive labels: 0.8458614498711562 | FPR: 0.4996976882107651
# Ratio of positive labels: 0.8460394387535349 | FPR: 0.4996807163040227
# Ratio of positive labels: 0.84621701705073 | FPR: 0.49967993116501597
# Ratio of positive labels: 0.8463941861818132 | FPR: 0.4996756916178668
# Ratio of positive labels: 0.8465697968126619 | FPR: 0.4996714618280071
# Ratio of positive labels: 0.846745003741375 | FPR: 0.4996442532824675
# Ratio of positive labels: 0.8469209564627366 | FPR: 0.49962169963065484
# Ratio of positive labels: 0.8470965056232733 | FPR: 0.499607225221072
# Ratio of positive labels: 0.8472716526097909 | FPR: 0.49960767513439275
# Ratio of positive labels: 0.8474463988027474 | FPR: 0.4996115565085166
# Ratio of positive labels: 0.8476207455762907 | FPR: 0.49959257189420353
# Ratio of positive labels: 0.8477935527470859 | FPR: 0.4995953200966666
# Ratio of positive labels: 0.8479659658312818 | FPR: 0.4996197267734016
# Ratio of positive labels: 0.8481379861754144 | FPR: 0.49964521680499224
# Ratio of positive labels: 0.8483096151198918 | FPR: 0.4996183167027114
# Ratio of positive labels: 0.8484819903613746 | FPR: 0.49961875043323817
# Ratio of positive labels: 0.8486539742860678 | FPR: 0.49963053390404777
# Ratio of positive labels: 0.8488255682249793 | FPR: 0.49963435415606106
# Ratio of positive labels: 0.8489967735030878 | FPR: 0.49961664822576646
# Ratio of positive labels: 0.8491675914393761 | FPR: 0.49962500042420765
# Ratio of positive labels: 0.8493368934046402 | FPR: 0.4996186444987068
# Ratio of positive labels: 0.8495058131988564 | FPR: 0.4996224609227303
# Ratio of positive labels: 0.8496754795090423 | FPR: 0.4996273961359683
# Ratio of positive labels: 0.8498436375634713 | FPR: 0.49960641936214034
# Ratio of positive labels: 0.8500125421681191 | FPR: 0.49958773949635604
# Ratio of positive labels: 0.8501799436180408 | FPR: 0.49958483192715514
# Ratio of positive labels: 0.8503480916407501 | FPR: 0.49957631921849693
# Ratio of positive labels: 0.8505158626503782 | FPR: 0.49956782559660806
# Ratio of positive labels: 0.850683257913485 | FPR: 0.49959294558460743
# Ratio of positive labels: 0.8508502786909634 | FPR: 0.49958109666544
# Ratio of positive labels: 0.8510158089208839 | FPR: 0.4995927378852091
# Ratio of positive labels: 0.8511820857342793 | FPR: 0.4996222102430689
# Ratio of positive labels: 0.8513479918082588 | FPR: 0.4996449279320759
# Ratio of positive labels: 0.8515135283813715 | FPR: 0.49965200484186545
# Ratio of positive labels: 0.8516786966866555 | FPR: 0.49965239193282324
# Ratio of positive labels: 0.8518412757319158 | FPR: 0.49966500037222183
# Ratio of positive labels: 0.8520057136451569 | FPR: 0.4996509437836362
# Ratio of positive labels: 0.8521686783052347 | FPR: 0.49963802700883925
# Ratio of positive labels: 0.852332389443644 | FPR: 0.49965060946776363
# Ratio of positive labels: 0.85249573838967 | FPR: 0.49962997828542227
# Ratio of positive labels: 0.8526587263439488 | FPR: 0.49963701697567187
# Ratio of positive labels: 0.8528213545018162 | FPR: 0.4996572851464844
# Ratio of positive labels: 0.8529836240533362 | FPR: 0.49967199595149286
# Ratio of positive labels: 0.8531455361833302 | FPR: 0.4997009915187318
# Ratio of positive labels: 0.8533070920714059 | FPR: 0.49971892220140574
# Ratio of positive labels: 0.8534671939920945 | FPR: 0.49970164867950695
# Ratio of positive labels: 0.8536280421207002 | FPR: 0.4997019761778527
# Ratio of positive labels: 0.853786344532517 | FPR: 0.49970778540813005
# Ratio of positive labels: 0.853946490748641 | FPR: 0.4996752467960057
# Ratio of positive labels: 0.8541062865357916 | FPR: 0.49963949711214756
# Ratio of positive labels: 0.8542657330429148 | FPR: 0.49963770531398327
# Ratio of positive labels: 0.8544248314139395 | FPR: 0.4996653933783915
# Ratio of positive labels: 0.8545824922764533 | FPR: 0.499691930543151
# Ratio of positive labels: 0.8547408989750556 | FPR: 0.49968028357267585
# Ratio of positive labels: 0.8548989609369304 | FPR: 0.49965886870634524
# Ratio of positive labels: 0.8550545053755376 | FPR: 0.4996472829920837
# Ratio of positive labels: 0.8552118835918745 | FPR: 0.4996693814664696
# Ratio of positive labels: 0.8553678358266422 | FPR: 0.49969360119999867
# Ratio of positive labels: 0.8555245335595519 | FPR: 0.49972318556534606
# Ratio of positive labels: 0.8556808921202467 | FPR: 0.4997061691491676
# Ratio of positive labels: 0.8558369126087432 | FPR: 0.4996978381644993
# Ratio of positive labels: 0.8559925961203065 | FPR: 0.49971004350967224
# Ratio of positive labels: 0.8561457862505003 | FPR: 0.4997049625620684
# Ratio of positive labels: 0.8562997238149528 | FPR: 0.4996955822245881
# Ratio of positive labels: 0.856453329974887 | FPR: 0.4997055977334793
# Ratio of positive labels: 0.8566076810670096 | FPR: 0.4997016132240718
# Ratio of positive labels: 0.8567617005781949 | FPR: 0.4996901184853722
# Ratio of positive labels: 0.8569153895757623 | FPR: 0.49969152393613314
# Ratio of positive labels: 0.857067677312243 | FPR: 0.4996897109435038
# Ratio of positive labels: 0.8572207096138013 | FPR: 0.4997168097250431
# Ratio of positive labels: 0.8573734145738882 | FPR: 0.4997171126020186
# Ratio of positive labels: 0.8575257932416739 | FPR: 0.4997216883315296
# Ratio of positive labels: 0.8576757121924096 | FPR: 0.4997102457734837
# Ratio of positive labels: 0.8578274436807637 | FPR: 0.499716951261246
# Ratio of positive labels: 0.8579788519927029 | FPR: 0.4997055381197677
# Ratio of positive labels: 0.8581299381596402 | FPR: 0.4996909577755768
# Ratio of positive labels: 0.8582796405104777 | FPR: 0.499680659212902
# Ratio of positive labels: 0.8584300865922647 | FPR: 0.4996703825155175
# Ratio of positive labels: 0.8585791531504209 | FPR: 0.49967073205648777
# Ratio of positive labels: 0.8587279038899324 | FPR: 0.49967319949872935
# Ratio of positive labels: 0.8588773980133354 | FPR: 0.49971375691665937
# Ratio of positive labels: 0.8590265760818435 | FPR: 0.4997225161495601
# Ratio of positive labels: 0.8591733271664972 | FPR: 0.49971858530244423
# Ratio of positive labels: 0.8593208235012411 | FPR: 0.4997473631356929
# Ratio of positive labels: 0.8594680089905069 | FPR: 0.49973919943182354
# Ratio of positive labels: 0.8596159372463819 | FPR: 0.4997563160459831
# Ratio of positive labels: 0.859763554402151 | FPR: 0.4997628814270437
# Ratio of positive labels: 0.8599108614381707 | FPR: 0.49976102966278396
# Ratio of positive labels: 0.8600578593306828 | FPR: 0.49973294886364233
# Ratio of positive labels: 0.8602045490518354 | FPR: 0.49978039855304135
# Ratio of positive labels: 0.8603509315697052 | FPR: 0.49981308920095374
# Ratio of positive labels: 0.8604970078483182 | FPR: 0.4997944562819495
# Ratio of positive labels: 0.8606417339166835 | FPR: 0.49979258119897474
# Ratio of positive labels: 0.8607872016835055 | FPR: 0.4997781839476159
# Ratio of positive labels: 0.860932366076782 | FPR: 0.4997711159842378
# Ratio of positive labels: 0.861075144713391 | FPR: 0.49979843770996074
# Ratio of positive labels: 0.8612197073676302 | FPR: 0.49979240396211866
# Ratio of positive labels: 0.8613639694761233 | FPR: 0.49980301475778094
# Ratio of positive labels: 0.8615079319751485 | FPR: 0.49977933563931914
# Ratio of positive labels: 0.8616515957970998 | FPR: 0.4997723031407644
# Ratio of positive labels: 0.8617939256021496 | FPR: 0.499775647900883
# Ratio of positive labels: 0.8619369959244348 | FPR: 0.4997841617141183
# Ratio of positive labels: 0.8620797703414992 | FPR: 0.49979989679431563
# Ratio of positive labels: 0.8622222497704032 | FPR: 0.49981250019369816
# Ratio of positive labels: 0.862364435124422 | FPR: 0.4998075337383553
# Ratio of positive labels: 0.8625063273130646 | FPR: 0.49979433010893803
# Ratio of positive labels: 0.8626479272420935 | FPR: 0.49980587043679664
# Ratio of positive labels: 0.8627892358135434 | FPR: 0.4997834364367938
# Ratio of positive labels: 0.8629292261775682 | FPR: 0.4997836590096002
# Ratio of positive labels: 0.8630699557803329 | FPR: 0.4997828544323876
# Ratio of positive labels: 0.8632103967072854 | FPR: 0.4998158976247204
# Ratio of positive labels: 0.8633505498457481 | FPR: 0.4998222337886949
# Ratio of positive labels: 0.8634904160794104 | FPR: 0.4998142274163486
# Ratio of positive labels: 0.8636299962883474 | FPR: 0.4997878325277786
# Ratio of positive labels: 0.8637682698996222 | FPR: 0.4997982637402822
# Ratio of positive labels: 0.8639072817272635 | FPR: 0.4997954083720323
# Ratio of positive labels: 0.8640460101467786 | FPR: 0.49980784932940947
# Ratio of positive labels: 0.8641844560239755 | FPR: 0.4998070266730889
# Ratio of positive labels: 0.8643216029281761 | FPR: 0.49980824027645954
# Ratio of positive labels: 0.8644594873379193 | FPR: 0.49980945141315913
# Ratio of positive labels: 0.8645970917796022 | FPR: 0.4998116753180961
# Ratio of positive labels: 0.8647344171050536 | FPR: 0.4998108521188112
# Ratio of positive labels: 0.8648714641626503 | FPR: 0.49978571450282216
# Ratio of positive labels: 0.8650082337973342 | FPR: 0.4997616399173685
# Ratio of positive labels: 0.86514472685063 | FPR: 0.4997942368106807
# Ratio of positive labels: 0.8652809441606625 | FPR: 0.49982777795173944
# Ratio of positive labels: 0.865416886562173 | FPR: 0.49982391541481797
# Ratio of positive labels: 0.8655525548865374 | FPR: 0.49983518161776047
# Ratio of positive labels: 0.8656869429134513 | FPR: 0.49984541808114996
# Ratio of positive labels: 0.8658220665773978 | FPR: 0.4998516098072336
# Ratio of positive labels: 0.8659569186362627 | FPR: 0.49985979913588025
# Ratio of positive labels: 0.8660914999081326 | FPR: 0.499865963989996
# Ratio of positive labels: 0.8662258112078123 | FPR: 0.49985707135699964
# Ratio of positive labels: 0.8663598533468403 | FPR: 0.49984719454188925
# Ratio of positive labels: 0.8664936271335064 | FPR: 0.49985935950014065
# Ratio of positive labels: 0.8666271333728667 | FPR: 0.4998775001224999
# Ratio of positive labels: 0.8667603728667603 | FPR: 0.49986763249986765
# Ratio of positive labels: 0.866893346413826 | FPR: 0.49988972066894144
# Ratio of positive labels: 0.8670260548095167 | FPR: 0.49989680967416783
# Ratio of positive labels: 0.8671584988461167 | FPR: 0.49991782876710283
# Ratio of positive labels: 0.8672906793127569 | FPR: 0.49994179110269543
# Ratio of positive labels: 0.8674225969954305 | FPR: 0.49995377738193103
# Ratio of positive labels: 0.8675542526770083 | FPR: 0.4999260179483436
# Ratio of positive labels: 0.8676856471372548 | FPR: 0.49992609134316335
# Ratio of positive labels: 0.8678167811528432 | FPR: 0.4999142716409597

# %%
model_preds[3]
# Out:
# 1

# %%
np.sum(model_preds)
# Out:
# 509939

# %% [markdown]
# ## Polya Random Process

# %%
iterations = 100000
init_samples = 10000
pos_p = 0.5
neg_p = 1 - pos_p

fpr = 0.01
tpr = 0.49
fnr = 0.01
tnr = 0.49

labels = np.array([int(init_samples * neg_p), int(init_samples * pos_p)])

# %%
for i in range(iterations):
    pos_p = float(labels[1]) / np.sum(labels)
    neg_p = 1 - pos_p
    
    new_sample = np.random.choice([0, 1], 1, p=[neg_p, pos_p])
    
    if new_sample == 1:
        labels[1] += 1
    else:
        switch = np.random.choice([0, 1], 1, [1 - fpr, fpr])
        
        if switch == 1:
            labels[1] += 1
        else:
            labels[0] += 1
            
    if i % 100 == 0:
        print("Ratio of positive labels: {}".format(float(labels[1]) / (labels[0] + labels[1])))
# Out:
# Ratio of positive labels: 0.5000499950005
# Ratio of positive labels: 0.503019503019503
# Ratio of positive labels: 0.5057347318890305
# Ratio of positive labels: 0.5079118532181341
# Ratio of positive labels: 0.5103355446591674
# Ratio of positive labels: 0.5126178459194363
# Ratio of positive labels: 0.5145740967833223
# Ratio of positive labels: 0.5168675824689282
# Ratio of positive labels: 0.5198592722896028
# Ratio of positive labels: 0.5216035226126043
# Ratio of positive labels: 0.5239523679665485
# Ratio of positive labels: 0.5252679938744257
# Ratio of positive labels: 0.5276314614766539
# Ratio of positive labels: 0.5303955402176799
# Ratio of positive labels: 0.5327602841855977
# Ratio of positive labels: 0.5349100078254065
# Ratio of positive labels: 0.5371950693905698
# Ratio of positive labels: 0.53935561063157
# Ratio of positive labels: 0.5413947970510974
# Ratio of positive labels: 0.542811528442988
# Ratio of positive labels: 0.5449545871177401
# Ratio of positive labels: 0.5465663994711181
# Ratio of positive labels: 0.548643553807065
# Ratio of positive labels: 0.551093407040078
# Ratio of positive labels: 0.5527780017740505
# Ratio of positive labels: 0.5542756579473642
# Ratio of positive labels: 0.5566224902785494
# Ratio of positive labels: 0.5584599637823794
# Ratio of positive labels: 0.5601124912116241
# Ratio of positive labels: 0.5619719401596776
# Ratio of positive labels: 0.5638797015614183
# Ratio of positive labels: 0.5659109991603695
# Ratio of positive labels: 0.5677600181804409
# Ratio of positive labels: 0.568979775956695
# Ratio of positive labels: 0.570106708454593
# Ratio of positive labels: 0.5718835641804311
# Ratio of positive labels: 0.5738548636129697
# Ratio of positive labels: 0.5754324501861178
# Ratio of positive labels: 0.5769871748424027
# Ratio of positive labels: 0.578519530968995
# Ratio of positive labels: 0.5803871152060567
# Ratio of positive labels: 0.5815899581589958
# Ratio of positive labels: 0.5837617069220478
# Ratio of positive labels: 0.5851339067198098
# Ratio of positive labels: 0.5868342476216929
# Ratio of positive labels: 0.5880284118336666
# Ratio of positive labels: 0.5900280802684748
# Ratio of positive labels: 0.5913883409291885
# Ratio of positive labels: 0.5925275319235187
# Ratio of positive labels: 0.594523857459231
# Ratio of positive labels: 0.5961602559829344
# Ratio of positive labels: 0.5976425402291239
# Ratio of positive labels: 0.5993684626011446
# Ratio of positive labels: 0.6007450493431802
# Ratio of positive labels: 0.6021686903447828
# Ratio of positive labels: 0.6034449390361912
# Ratio of positive labels: 0.6046407281584514
# Ratio of positive labels: 0.6058212852684542
# Ratio of positive labels: 0.6067337510284159
# Ratio of positive labels: 0.6081378529652223
# Ratio of positive labels: 0.6091494281607399
# Ratio of positive labels: 0.6103347618160363
# Ratio of positive labels: 0.611567187210666
# Ratio of positive labels: 0.6129685295380651
# Ratio of positive labels: 0.6142918114749101
# Ratio of positive labels: 0.6155990546027513
# Ratio of positive labels: 0.6168905487621228
# Ratio of positive labels: 0.6177474402730375
# Ratio of positive labels: 0.6185941313017083
# Ratio of positive labels: 0.6197266433938821
# Ratio of positive labels: 0.6208458325980825
# Ratio of positive labels: 0.6223612654230747
# Ratio of positive labels: 0.6235683971862102
# Ratio of positive labels: 0.624992774984105
# Ratio of positive labels: 0.6260559737946095
# Ratio of positive labels: 0.6269356036797897
# Ratio of positive labels: 0.6285438327367763
# Ratio of positive labels: 0.6295689509067285
# Ratio of positive labels: 0.6310319644963767
# Ratio of positive labels: 0.6318082788671024
# Ratio of positive labels: 0.6329092828176213
# Ratio of positive labels: 0.6339981216507375
# Ratio of positive labels: 0.6349651118070435
# Ratio of positive labels: 0.6358122506966832
# Ratio of positive labels: 0.637030596163252
# Ratio of positive labels: 0.6381817199070321
# Ratio of positive labels: 0.6393204666415784
# Ratio of positive labels: 0.6401796695363884
# Ratio of positive labels: 0.6410297324610393
# Ratio of positive labels: 0.6418178932331623
# Ratio of positive labels: 0.6427556444397663
# Ratio of positive labels: 0.643892989895817
# Ratio of positive labels: 0.6446539242747773
# Ratio of positive labels: 0.6453551629449251
# Ratio of positive labels: 0.6462553476624916
# Ratio of positive labels: 0.6474026972975745
# Ratio of positive labels: 0.6479771440232641
# Ratio of positive labels: 0.6490533475458099
# Ratio of positive labels: 0.6500176758749558
# Ratio of positive labels: 0.6508215667554395
# Ratio of positive labels: 0.6514674266286685
# Ratio of positive labels: 0.652654096811104
# Ratio of positive labels: 0.6535815058660462
# Ratio of positive labels: 0.6546475543076695
# Ratio of positive labels: 0.6554580657810891
# Ratio of positive labels: 0.6565533388615189
# Ratio of positive labels: 0.6571525654094461
# Ratio of positive labels: 0.6580841505241293
# Ratio of positive labels: 0.6591510023556559
# Ratio of positive labels: 0.6599205779627769
# Ratio of positive labels: 0.6606352078472454
# Ratio of positive labels: 0.6613430643097483
# Ratio of positive labels: 0.6619499080232064
# Ratio of positive labels: 0.6628327308577062
# Ratio of positive labels: 0.6634269426662306
# Ratio of positive labels: 0.6641086461094833
# Ratio of positive labels: 0.6645525670107866
# Ratio of positive labels: 0.665314962444127
# Ratio of positive labels: 0.6659786248337233
# Ratio of positive labels: 0.6670928268115611
# Ratio of positive labels: 0.667969637743739
# Ratio of positive labels: 0.6686122799873309
# Ratio of positive labels: 0.6695193910184226
# Ratio of positive labels: 0.670104479619748
# Ratio of positive labels: 0.6709521896343913
# Ratio of positive labels: 0.6720145771299053
# Ratio of positive labels: 0.6726693509136764
# Ratio of positive labels: 0.6732743050966917
# Ratio of positive labels: 0.6741370992500328
# Ratio of positive labels: 0.6747740273350509
# Ratio of positive labels: 0.6755793226381461
# Ratio of positive labels: 0.6761612051426346
# Ratio of positive labels: 0.6768242748157407
# Ratio of positive labels: 0.6774816531479335
# Ratio of positive labels: 0.6779197470193582
# Ratio of positive labels: 0.6784392153525381
# Ratio of positive labels: 0.6790813948561502
# Ratio of positive labels: 0.68005569385258
# Ratio of positive labels: 0.680727700516785
# Ratio of positive labels: 0.6816032801974813
# Ratio of positive labels: 0.6821382442398234
# Ratio of positive labels: 0.682751753039293
# Ratio of positive labels: 0.6834015123342011
# Ratio of positive labels: 0.6840047734661125
# Ratio of positive labels: 0.6847260358182041
# Ratio of positive labels: 0.6854414105546712
# Ratio of positive labels: 0.6861916182269013
# Ratio of positive labels: 0.6868547832071576
# Ratio of positive labels: 0.687310995524374
# Ratio of positive labels: 0.6876832255732701
# Ratio of positive labels: 0.6881324747010119
# Ratio of positive labels: 0.6887375004979881
# Ratio of positive labels: 0.6894567675885878
# Ratio of positive labels: 0.6901703489980633
# Ratio of positive labels: 0.6904058895319082
# Ratio of positive labels: 0.6911493666915023
# Ratio of positive labels: 0.6916526698175852
# Ratio of positive labels: 0.6921909653320882
# Ratio of positive labels: 0.6928413627378783
# Ratio of positive labels: 0.6934095208679202
# Ratio of positive labels: 0.6940502288373525
# Ratio of positive labels: 0.6946860273552737
# Ratio of positive labels: 0.6950498072592649
# Ratio of positive labels: 0.6956009277213794
# Ratio of positive labels: 0.6961478731866217
# Ratio of positive labels: 0.6969170974680201
# Ratio of positive labels: 0.6972670200368407
# Ratio of positive labels: 0.6978390322459833
# Ratio of positive labels: 0.6986306481101452
# Ratio of positive labels: 0.6991933385376008
# Ratio of positive labels: 0.6997148253768379
# Ratio of positive labels: 0.7005276558060588
# Ratio of positive labels: 0.7008933495092092
# Ratio of positive labels: 0.7015127651001795
# Ratio of positive labels: 0.702164154592898
# Ratio of positive labels: 0.7026289953092615
# Ratio of positive labels: 0.7030542371653201
# Ratio of positive labels: 0.7037291072524458
# Ratio of positive labels: 0.7043631524045898
# Ratio of positive labels: 0.7047776065374001
# Ratio of positive labels: 0.7051891003892719
# Ratio of positive labels: 0.7056332514857122
# Ratio of positive labels: 0.7060387929506046
# Ratio of positive labels: 0.7066534751422211
# Ratio of positive labels: 0.707158198654977
# Ratio of positive labels: 0.7078348128135855
# Ratio of positive labels: 0.7084367679451767
# Ratio of positive labels: 0.7091042123967806
# Ratio of positive labels: 0.7097670219784036
# Ratio of positive labels: 0.7103560430434933
# Ratio of positive labels: 0.7110444467432158
# Ratio of positive labels: 0.7116250300676953
# Ratio of positive labels: 0.7121331461251327
# Ratio of positive labels: 0.7127401795160575
# Ratio of positive labels: 0.7131730213258053
# Ratio of positive labels: 0.713670723026338
# Ratio of positive labels: 0.7141312793486706
# Ratio of positive labels: 0.7145213965859736
# Ratio of positive labels: 0.714942451595584
# Ratio of positive labels: 0.7151934717902412
# Ratio of positive labels: 0.7157094763507883
# Ratio of positive labels: 0.7161888309358493
# Ratio of positive labels: 0.7162676732558525
# Ratio of positive labels: 0.7166760172931587
# Ratio of positive labels: 0.7171145685997171
# Ratio of positive labels: 0.7174518868233828
# Ratio of positive labels: 0.7180484297898762
# Ratio of positive labels: 0.7183805087782157
# Ratio of positive labels: 0.7188078309145807
# Ratio of positive labels: 0.7190705802401217
# Ratio of positive labels: 0.7194929195832392
# Ratio of positive labels: 0.7201376161538214
# Ratio of positive labels: 0.7205217781481362
# Ratio of positive labels: 0.7209354333727357
# Ratio of positive labels: 0.7215375306518901
# Ratio of positive labels: 0.721881845020793
# Ratio of positive labels: 0.7222556248219993
# Ratio of positive labels: 0.7227532254503013
# Ratio of positive labels: 0.7233734788214207
# Ratio of positive labels: 0.7237077207611047
# Ratio of positive labels: 0.7241648698478172
# Ratio of positive labels: 0.7245568673873088
# Ratio of positive labels: 0.7249464302350859
# Ratio of positive labels: 0.7254574161790657
# Ratio of positive labels: 0.7257800685164039
# Ratio of positive labels: 0.7262853450663056
# Ratio of positive labels: 0.7266955001380325
# Ratio of positive labels: 0.7271337267973457
# Ratio of positive labels: 0.7273558732965458
# Ratio of positive labels: 0.7276678520409714
# Ratio of positive labels: 0.7280082421744796
# Ratio of positive labels: 0.7284372073351258
# Ratio of positive labels: 0.728953947170266
# Ratio of positive labels: 0.7294075252995406
# Ratio of positive labels: 0.7298284482500524
# Ratio of positive labels: 0.7300379093161398
# Ratio of positive labels: 0.7302758846462903
# Ratio of positive labels: 0.730631138541883
# Ratio of positive labels: 0.7308659507115174
# Ratio of positive labels: 0.7313058611840358
# Ratio of positive labels: 0.7317431840239993
# Ratio of positive labels: 0.732089968036128
# Ratio of positive labels: 0.732639396508874
# Ratio of positive labels: 0.7331564677414653
# Ratio of positive labels: 0.7336123949885178
# Ratio of positive labels: 0.7340946639227849
# Ratio of positive labels: 0.7346030461547354
# Ratio of positive labels: 0.7351084983141696
# Ratio of positive labels: 0.7353811672078389
# Ratio of positive labels: 0.7358241884186699
# Ratio of positive labels: 0.7362361075397845
# Ratio of positive labels: 0.7366741688270989
# Ratio of positive labels: 0.7371665577682452
# Ratio of positive labels: 0.7374295345740914
# Ratio of positive labels: 0.7377475212564617
# Ratio of positive labels: 0.7382608940593223
# Ratio of positive labels: 0.7386590264318418
# Ratio of positive labels: 0.7391109492731296
# Ratio of positive labels: 0.7394206865730008
# Ratio of positive labels: 0.7398958246288404
# Ratio of positive labels: 0.7403683231021361
# Ratio of positive labels: 0.7407551037367386
# Ratio of positive labels: 0.741084500428165
# Ratio of positive labels: 0.7414396297622655
# Ratio of positive labels: 0.7416829207988791
# Ratio of positive labels: 0.7421988438672913
# Ratio of positive labels: 0.7425753394715991
# Ratio of positive labels: 0.7430042778125937
# Ratio of positive labels: 0.7432678459824461
# Ratio of positive labels: 0.7435570851738436
# Ratio of positive labels: 0.7438447609524067
# Ratio of positive labels: 0.7441578394113366
# Ratio of positive labels: 0.7446305206849279
# Ratio of positive labels: 0.7451006675424251
# Ratio of positive labels: 0.745488088553782
# Ratio of positive labels: 0.7457934455081198
# Ratio of positive labels: 0.7461503683412675
# Ratio of positive labels: 0.7464258242486936
# Ratio of positive labels: 0.7466204597761964
# Ratio of positive labels: 0.7468932218147278
# Ratio of positive labels: 0.7472171784953028
# Ratio of positive labels: 0.747434450539356
# Ratio of positive labels: 0.7477814716892228
# Ratio of positive labels: 0.7479700268922482
# Ratio of positive labels: 0.7483659279706257
# Ratio of positive labels: 0.7486558790680762
# Ratio of positive labels: 0.7490220460609829
# Ratio of positive labels: 0.7492571251388853
# Ratio of positive labels: 0.7496714002216438
# Ratio of positive labels: 0.7499807202899669
# Ratio of positive labels: 0.7504422963513756
# Ratio of positive labels: 0.7508759366768113
# Ratio of positive labels: 0.7511287977347517
# Ratio of positive labels: 0.7513803720007125
# Ratio of positive labels: 0.751808329737824
# Ratio of positive labels: 0.7520569099516468
# Ratio of positive labels: 0.7523547385167041
# Ratio of positive labels: 0.7526258784413491
# Ratio of positive labels: 0.7529207808849024
# Ratio of positive labels: 0.7533144532718479
# Ratio of positive labels: 0.7536561585960351
# Ratio of positive labels: 0.7538714745268198
# Ratio of positive labels: 0.7541105942638243
# Ratio of positive labels: 0.7544477804520979
# Ratio of positive labels: 0.7547832974431326
# Ratio of positive labels: 0.7550183946075405
# Ratio of positive labels: 0.7552769636215857
# Ratio of positive labels: 0.7556816785828357
# Ratio of positive labels: 0.7560353912894292
# Ratio of positive labels: 0.756314026551918
# Ratio of positive labels: 0.7565425233530889
# Ratio of positive labels: 0.7568672295077978
# Ratio of positive labels: 0.7571418169461906
# Ratio of positive labels: 0.7575361371395366
# Ratio of positive labels: 0.757904398444482
# Ratio of positive labels: 0.758222693429074
# Ratio of positive labels: 0.7584673445349871
# Ratio of positive labels: 0.7586149013213113
# Ratio of positive labels: 0.7589052893471449
# Ratio of positive labels: 0.7590749624113983
# Ratio of positive labels: 0.7593152543987048
# Ratio of positive labels: 0.7596256620982874
# Ratio of positive labels: 0.7600056870690268
# Ratio of positive labels: 0.7602657147585163
# Ratio of positive labels: 0.7605481002806538
# Ratio of positive labels: 0.7608056281028681
# Ratio of positive labels: 0.7610619469026548
# Ratio of positive labels: 0.7614107397953209
# Ratio of positive labels: 0.7615709913319783
# Ratio of positive labels: 0.7617304957926389
# Ratio of positive labels: 0.7618660031162066
# Ratio of positive labels: 0.7621864921927566
# Ratio of positive labels: 0.7624360547209555
# Ratio of positive labels: 0.7626844645620193
# Ratio of positive labels: 0.7629547706274049
# Ratio of positive labels: 0.7633387738212914
# Ratio of positive labels: 0.7636063393041445
# Ratio of positive labels: 0.763872680259033
# Ratio of positive labels: 0.7640693134859935
# Ratio of positive labels: 0.7643561650076308
# Ratio of positive labels: 0.7645508056635076
# Ratio of positive labels: 0.7648579397292579
# Ratio of positive labels: 0.7650958123119387
# Ratio of positive labels: 0.765310038148123
# Ratio of positive labels: 0.7655007770095268
# Ratio of positive labels: 0.7658479584728433
# Ratio of positive labels: 0.7660142149279164
# Ratio of positive labels: 0.7662915818438066
# Ratio of positive labels: 0.7664561058904935
# Ratio of positive labels: 0.7667757956392953
# Ratio of positive labels: 0.7670940645763428
# Ratio of positive labels: 0.7674330946098756
# Ratio of positive labels: 0.7677706245437048
# Ratio of positive labels: 0.7679521423368137
# Ratio of positive labels: 0.7682429902425056
# Ratio of positive labels: 0.7684226720291861
# Ratio of positive labels: 0.7686673537861012
# Ratio of positive labels: 0.7689109647491302
# Ratio of positive labels: 0.769197179100893
# Ratio of positive labels: 0.769373216269798
# Ratio of positive labels: 0.7695919653920567
# Ratio of positive labels: 0.7698097655148478
# Ratio of positive labels: 0.7700699119066687
# Ratio of positive labels: 0.7702857389689207
# Ratio of positive labels: 0.7705868408008448
# Ratio of positive labels: 0.7708866475989764
# Ratio of positive labels: 0.7712280852342225
# Ratio of positive labels: 0.7715252350056744
# Ratio of positive labels: 0.7717997478686353
# Ratio of positive labels: 0.7720304471120019
# Ratio of positive labels: 0.7723452692495905
# Ratio of positive labels: 0.7726799855629393
# Ratio of positive labels: 0.7730344696086947
# Ratio of positive labels: 0.7733663136085918
# Ratio of positive labels: 0.7735701778443492
# Ratio of positive labels: 0.773794235910823
# Ratio of positive labels: 0.774101384424697
# Ratio of positive labels: 0.7743024255256703
# Ratio of positive labels: 0.7746072257902554
# Ratio of positive labels: 0.7747646186927204
# Ratio of positive labels: 0.7750255203016604
# Ratio of positive labels: 0.7753477058689009
# Ratio of positive labels: 0.7755855687641335
# Ratio of positive labels: 0.7758017432351297
# Ratio of positive labels: 0.7758930600607425
# Ratio of positive labels: 0.7761077091193996
# Ratio of positive labels: 0.776177444908541
# Ratio of positive labels: 0.7763906285291883
# Ratio of positive labels: 0.7767463781479887
# Ratio of positive labels: 0.7769166274718309
# Ratio of positive labels: 0.7772698516356809
# Ratio of positive labels: 0.7774994399299403
# Ratio of positive labels: 0.777707770167273
# Ratio of positive labels: 0.7779761059613395
# Ratio of positive labels: 0.778243355397664
# Ratio of positive labels: 0.7783681137754793
# Ratio of positive labels: 0.7785730126408742
# Ratio of positive labels: 0.7787770869801413
# Ratio of positive labels: 0.7790405815144275
# Ratio of positive labels: 0.7793230596581231
# Ratio of positive labels: 0.7795244095118098
# Ratio of positive labels: 0.7796850362268218
# Ratio of positive labels: 0.7799446226170793
# Ratio of positive labels: 0.7801832965547405
# Ratio of positive labels: 0.7803218190115275
# Ratio of positive labels: 0.7804597928753886
# Ratio of positive labels: 0.7806367463093615
# Ratio of positive labels: 0.7808918956233605
# Ratio of positive labels: 0.781146040432275
# Ratio of positive labels: 0.7813009567591992
# Ratio of positive labels: 0.7815729103350915
# Ratio of positive labels: 0.7818437995342556
# Ratio of positive labels: 0.7820550379875393
# Ratio of positive labels: 0.7823239313073819
# Ratio of positive labels: 0.7825528686212331
# Ratio of positive labels: 0.782878002368886
# Ratio of positive labels: 0.7831631169938567
# Ratio of positive labels: 0.7833504187539893
# Ratio of positive labels: 0.7836528252350341
# Ratio of positive labels: 0.7837999267836844
# Ratio of positive labels: 0.7840233841656892
# Ratio of positive labels: 0.7843035642310129
# Ratio of positive labels: 0.7845252006666539
# Ratio of positive labels: 0.7848033498403473
# Ratio of positive labels: 0.7849659357645846
# Ratio of positive labels: 0.7851469495819128
# Ratio of positive labels: 0.7854033193285299
# Ratio of positive labels: 0.785601791237358
# Ratio of positive labels: 0.7857616333023996
# Ratio of positive labels: 0.7860531937014423
# Ratio of positive labels: 0.7862870511877135
# Ratio of positive labels: 0.7864446997231691
# Ratio of positive labels: 0.786733332080224
# Ratio of positive labels: 0.7869458359130223
# Ratio of positive labels: 0.787194996348383
# Ratio of positive labels: 0.7873497691631932
# Ratio of positive labels: 0.7875039644782746
# Ratio of positive labels: 0.787713450401296
# Ratio of positive labels: 0.7879593316109366
# Ratio of positive labels: 0.7881671954138142
# Ratio of positive labels: 0.7883928075406011
# Ratio of positive labels: 0.7884512301066524
# Ratio of positive labels: 0.7886939355362447
# Ratio of positive labels: 0.7888804994383161
# Ratio of positive labels: 0.7891031414863697
# Ratio of positive labels: 0.7892882699400011
# Ratio of positive labels: 0.7895093496456109
# Ratio of positive labels: 0.7896382150234913
# Ratio of positive labels: 0.7898031057827412
# Ratio of positive labels: 0.7899309666490593
# Ratio of positive labels: 0.7901674515008819
# Ratio of positive labels: 0.7902760385473948
# Ratio of positive labels: 0.7905291570804877
# Ratio of positive labels: 0.7907090287698233
# Ratio of positive labels: 0.7909604519774012
# Ratio of positive labels: 0.7912109691717266
# Ratio of positive labels: 0.7914246146652039
# Ratio of positive labels: 0.7916913520403583
# Ratio of positive labels: 0.7918316876041648
# Ratio of positive labels: 0.7920609649201267
# Ratio of positive labels: 0.7922894234031536
# Ratio of positive labels: 0.7924814174435393
# Ratio of positive labels: 0.7927083147986691
# Ratio of positive labels: 0.7928633594429939
# Ratio of positive labels: 0.7931242353858974
# Ratio of positive labels: 0.7932956938815242
# Ratio of positive labels: 0.793501881592198
# Ratio of positive labels: 0.7937073420221865
# Ratio of positive labels: 0.7939648949842433
# Ratio of positive labels: 0.7940985219943411
# Ratio of positive labels: 0.7941965930422273
# Ratio of positive labels: 0.7943993975587118
# Ratio of positive labels: 0.7946189751927414
# Ratio of positive labels: 0.7948552381284795
# Ratio of positive labels: 0.795090677862755
# Ratio of positive labels: 0.7953252986904575
# Ratio of positive labels: 0.7954896616378188
# Ratio of positive labels: 0.7956707856016361
# Ratio of positive labels: 0.7959204858047438
# Ratio of positive labels: 0.7960829692060586
# Ratio of positive labels: 0.7962966155755935
# Ratio of positive labels: 0.7964406808832895
# Ratio of positive labels: 0.7966873421418876
# Ratio of positive labels: 0.7968645477779112
# Ratio of positive labels: 0.7970069005667711
# Ratio of positive labels: 0.7972000478624297
# Ratio of positive labels: 0.7972389549666388
# Ratio of positive labels: 0.7974651198446364
# Ratio of positive labels: 0.797588476386456
# Ratio of positive labels: 0.7977623469890155
# Ratio of positive labels: 0.7979017304791444
# Ratio of positive labels: 0.7980406422903166
# Ratio of positive labels: 0.7981453015996351
# Ratio of positive labels: 0.7983507866646431
# Ratio of positive labels: 0.7986060840726588
# Ratio of positive labels: 0.7987092653904977
# Ratio of positive labels: 0.7989127699199677
# Ratio of positive labels: 0.7990988425654512
# Ratio of positive labels: 0.799284292904801
# Ratio of positive labels: 0.7994023472062236
# Ratio of positive labels: 0.7995533407776537
# Ratio of positive labels: 0.7996705545664797
# Ratio of positive labels: 0.799870434045946
# Ratio of positive labels: 0.8000862340591367
# Ratio of positive labels: 0.8003178755318621
# Ratio of positive labels: 0.8005322226078908
# Ratio of positive labels: 0.8006468540123101
# Ratio of positive labels: 0.8007446335315728
# Ratio of positive labels: 0.8008749856087893
# Ratio of positive labels: 0.801054169882268
# Ratio of positive labels: 0.8012819461976033
# Ratio of positive labels: 0.8014926105955713
# Ratio of positive labels: 0.8016045489452787
# Ratio of positive labels: 0.8018139997716187
# Ratio of positive labels: 0.8018436181821142
# Ratio of positive labels: 0.801938179866994
# Ratio of positive labels: 0.8020973685492119
# Ratio of positive labels: 0.8022722484238505
# Ratio of positive labels: 0.8024303813854144
# Ratio of positive labels: 0.8025556937690829
# Ratio of positive labels: 0.8027289882421251
# Ratio of positive labels: 0.8028534162090788
# Ratio of positive labels: 0.8029452902686453
# Ratio of positive labels: 0.8031331760324875
# Ratio of positive labels: 0.8033204596080191
# Ratio of positive labels: 0.8033471464456569
# Ratio of positive labels: 0.8034536189517739
# Ratio of positive labels: 0.8036075979649447
# Ratio of positive labels: 0.8037451632935781
# Ratio of positive labels: 0.8039140872164194
# Ratio of positive labels: 0.8040666021174268
# Ratio of positive labels: 0.8042978716660591
# Ratio of positive labels: 0.8043860065505293
# Ratio of positive labels: 0.8046002432820967
# Ratio of positive labels: 0.8047822589549061
# Ratio of positive labels: 0.8049322057920347
# Ratio of positive labels: 0.8050974041288659
# Ratio of positive labels: 0.8053091788197988
# Ratio of positive labels: 0.8054419209730255
# Ratio of positive labels: 0.8055898968717234
# Ratio of positive labels: 0.8057686598646896
# Ratio of positive labels: 0.8060404673874042
# Ratio of positive labels: 0.8061245151944674
# Ratio of positive labels: 0.8062705090123016
# Ratio of positive labels: 0.806400521731029
# Ratio of positive labels: 0.8065456349513961
# Ratio of positive labels: 0.8067057785483197
# Ratio of positive labels: 0.8068499714069335
# Ratio of positive labels: 0.8070400148145862
# Ratio of positive labels: 0.807183248332075
# Ratio of positive labels: 0.8073568098952324
# Ratio of positive labels: 0.8074837560098923
# Ratio of positive labels: 0.8076256499133448
# Ratio of positive labels: 0.8077671092326304
# Ratio of positive labels: 0.8078775553890614
# Ratio of positive labels: 0.808002931252958
# Ratio of positive labels: 0.8080669501989299
# Ratio of positive labels: 0.808145994733718
# Ratio of positive labels: 0.8082855883649185
# Ratio of positive labels: 0.8084551069027784
# Ratio of positive labels: 0.808533204042363
# Ratio of positive labels: 0.8087018350705738
# Ratio of positive labels: 0.8088095345991753
# Ratio of positive labels: 0.8088867437896864
# Ratio of positive labels: 0.8090239604825229
# Ratio of positive labels: 0.8091156523962045
# Ratio of positive labels: 0.8092671281211994
# Ratio of positive labels: 0.8093431882580471
# Ratio of positive labels: 0.809448960344905
# Ratio of positive labels: 0.8095544162269622
# Ratio of positive labels: 0.8097192579215235
# Ratio of positive labels: 0.8098836082919778
# Ratio of positive labels: 0.8100325888007619
# Ratio of positive labels: 0.8101959852008143
# Ratio of positive labels: 0.8103737333273987
# Ratio of positive labels: 0.810565769396009
# Ratio of positive labels: 0.8107276519578113
# Ratio of positive labels: 0.8108152021388163
# Ratio of positive labels: 0.8109467411985074
# Ratio of positive labels: 0.8110926201381423
# Ratio of positive labels: 0.8112674813605683
# Ratio of positive labels: 0.8114418290480316
# Ratio of positive labels: 0.8115863403762408
# Ratio of positive labels: 0.811730428544238
# Ratio of positive labels: 0.8118740954079618
# Ratio of positive labels: 0.8119151545232917
# Ratio of positive labels: 0.8120872873573272
# Ratio of positive labels: 0.8122443632552656
# Ratio of positive labels: 0.8123428438540138
# Ratio of positive labels: 0.812513606478861
# Ratio of positive labels: 0.8126693816031652
# Ratio of positive labels: 0.8128681205771262
# Ratio of positive labels: 0.8130373838528345
# Ratio of positive labels: 0.8132205884474971
# Ratio of positive labels: 0.813331220011239
# Ratio of positive labels: 0.8135278629084474
# Ratio of positive labels: 0.8137095731383169
# Ratio of positive labels: 0.8138190269867004
# Ratio of positive labels: 0.8139281672182347
# Ratio of positive labels: 0.8140942189668245
# Ratio of positive labels: 0.8142883673090384
# Ratio of positive labels: 0.8143821058187473
# Ratio of positive labels: 0.8145468013276164
# Ratio of positive labels: 0.8146399055489965
# Ratio of positive labels: 0.8147611539608812
# Ratio of positive labels: 0.8148253216266436
# Ratio of positive labels: 0.8149742921488364
# Ratio of positive labels: 0.815108697189573
# Ratio of positive labels: 0.8152709707490007
# Ratio of positive labels: 0.8153763698678439
# Ratio of positive labels: 0.8154955564006141
# Ratio of positive labels: 0.8156425366731832
# Ratio of positive labels: 0.8157891040856168
# Ratio of positive labels: 0.8158791601800817
# Ratio of positive labels: 0.8160529964566322
# Ratio of positive labels: 0.8162263464846645
# Ratio of positive labels: 0.81637127973073
# Ratio of positive labels: 0.8165576491262325
# Ratio of positive labels: 0.816618152950516
# Ratio of positive labels: 0.8167619365516474
# Ratio of positive labels: 0.8169469868474049
# Ratio of positive labels: 0.817034437802527
# Ratio of positive labels: 0.8171493469619534
# Ratio of positive labels: 0.8172777693254588
# Ratio of positive labels: 0.8174472728277233
# Ratio of positive labels: 0.8176163087405691
# Ratio of positive labels: 0.8177435572512776
# Ratio of positive labels: 0.8178567007331399
# Ratio of positive labels: 0.8179970055356383
# Ratio of positive labels: 0.8181369254194044
# Ratio of positive labels: 0.818207969753839
# Ratio of positive labels: 0.8183061791220366
# Ratio of positive labels: 0.8184724252400923
# Ratio of positive labels: 0.818583648244908
# Ratio of positive labels: 0.8185719540605714
# Ratio of positive labels: 0.818737160038639
# Ratio of positive labels: 0.8188611567777612
# Ratio of positive labels: 0.8189576803571186
# Ratio of positive labels: 0.8191352420698906
# Ratio of positive labels: 0.8192581967767689
# Ratio of positive labels: 0.819421359170822
# Ratio of positive labels: 0.8194896155247567
# Ratio of positive labels: 0.8195981186237382
# Ratio of positive labels: 0.8196928708900284
# Ratio of positive labels: 0.8198545718471526
# Ratio of positive labels: 0.8199889934363297
# Ratio of positive labels: 0.8201096500046916
# Ratio of positive labels: 0.8202165968327064
# Ratio of positive labels: 0.8203633641261481
# Ratio of positive labels: 0.8204963885662407
# Ratio of positive labels: 0.820629058279223
# Ratio of positive labels: 0.8208146362897965
# Ratio of positive labels: 0.8209332322708475
# Ratio of positive labels: 0.821051513260116
# Ratio of positive labels: 0.8211960053580192
# Ratio of positive labels: 0.8212474006966796
# Ratio of positive labels: 0.821391251438473
# Ratio of positive labels: 0.8214818826699779
# Ratio of positive labels: 0.8215722747721006
# Ratio of positive labels: 0.8217151289179325
# Ratio of positive labels: 0.8218312916935303
# Ratio of positive labels: 0.8219340087515276
# Ratio of positive labels: 0.8220889489639244
# Ratio of positive labels: 0.8222303770592784
# Ratio of positive labels: 0.8222798130914517
# Ratio of positive labels: 0.8224206219526542
# Ratio of positive labels: 0.8225349538517774
# Ratio of positive labels: 0.82264898762728
# Ratio of positive labels: 0.822788765771279
# Ratio of positive labels: 0.8229151766557001
# Ratio of positive labels: 0.8230282723600992
# Ratio of positive labels: 0.8231410746942323
# Ratio of positive labels: 0.8232147251978601
# Ratio of positive labels: 0.8233011215896301
# Ratio of positive labels: 0.8234260539269519
# Ratio of positive labels: 0.8235635669217172
# Ratio of positive labels: 0.8237007255061146
# Ratio of positive labels: 0.8238504008957414
# Ratio of positive labels: 0.8239097183840824
# Ratio of positive labels: 0.8240459044171449
# Ratio of positive labels: 0.8241561005628133
# Ratio of positive labels: 0.8242404066529238
# Ratio of positive labels: 0.8243244971291928
# Ratio of positive labels: 0.8244083728177163
# Ratio of positive labels: 0.8245175444190763
# Ratio of positive labels: 0.8245372670411842
# Ratio of positive labels: 0.8246587193547156
# Ratio of positive labels: 0.8247417440693257
# Ratio of positive labels: 0.8248753188411314
# Ratio of positive labels: 0.8249958809140568
# Ratio of positive labels: 0.8251414539056467
# Ratio of positive labels: 0.8252866588285862
# Ratio of positive labels: 0.8254567492834687
# Ratio of positive labels: 0.8256011904011299
# Ratio of positive labels: 0.8256822961927431
# Ratio of positive labels: 0.8258512471541238
# Ratio of positive labels: 0.8259443976834462
# Ratio of positive labels: 0.8260373144628047
# Ratio of positive labels: 0.826180123056102
# Ratio of positive labels: 0.8263100586976383
# Ratio of positive labels: 0.8264396695041312
# Ratio of positive labels: 0.82653150397623
# Ratio of positive labels: 0.8265981720926173
# Ratio of positive labels: 0.8267393930337107
# Ratio of positive labels: 0.8268802626833
# Ratio of positive labels: 0.8269959379386591
# Ratio of positive labels: 0.8271857669259687
# Ratio of positive labels: 0.8272883855218647
# Ratio of positive labels: 0.8274031261989332
# Ratio of positive labels: 0.8274928616457151
# Ratio of positive labels: 0.8275947210528265
# Ratio of positive labels: 0.8276470080516887
# Ratio of positive labels: 0.8277607418627849
# Ratio of positive labels: 0.8279110958044796
# Ratio of positive labels: 0.8280242257466125
# Ratio of positive labels: 0.8281616176488632
# Ratio of positive labels: 0.8282619085550422
# Ratio of positive labels: 0.828300755192715
# Ratio of positive labels: 0.8284373051674185
# Ratio of positive labels: 0.8285124723751847
# Ratio of positive labels: 0.8286606260899257
# Ratio of positive labels: 0.8287718785398472
# Ratio of positive labels: 0.8288463643994599
# Ratio of positive labels: 0.8289206692506774
# Ratio of positive labels: 0.8290433368527081
# Ratio of positive labels: 0.8291535860171392
# Ratio of positive labels: 0.8292151426738175
# Ratio of positive labels: 0.8293249174737911
# Ratio of positive labels: 0.8294465042692721
# Ratio of positive labels: 0.8295677977346474
# Ratio of positive labels: 0.8296647028349056
# Ratio of positive labels: 0.8297493411631629
# Ratio of positive labels: 0.8297856996911095
# Ratio of positive labels: 0.8299060035293694
# Ratio of positive labels: 0.8300140286087697
# Ratio of positive labels: 0.830157722662004
# Ratio of positive labels: 0.8302532266360451
# Ratio of positive labels: 0.8303365551188158
# Ratio of positive labels: 0.8304793498884262
# Ratio of positive labels: 0.8306218042693174
# Ratio of positive labels: 0.8307639194771491
# Ratio of positive labels: 0.8308224634665462
# Ratio of positive labels: 0.8309521264593057
# Ratio of positive labels: 0.8310696195774665
# Ratio of positive labels: 0.831174986078364
# Ratio of positive labels: 0.8313156057324765
# Ratio of positive labels: 0.8313967920000945
# Ratio of positive labels: 0.8314895928029185
# Ratio of positive labels: 0.8315821747385055
# Ratio of positive labels: 0.8316980954287936
# Ratio of positive labels: 0.8317902142327738
# Ratio of positive labels: 0.8318821165438715
# Ratio of positive labels: 0.832055961784486
# Ratio of positive labels: 0.8320887211169857
# Ratio of positive labels: 0.8322150794487184
# Ratio of positive labels: 0.8323294464392229
# Ratio of positive labels: 0.8324552283267719
# Ratio of positive labels: 0.832557379727191
# Ratio of positive labels: 0.8326359832635983
# Ratio of positive labels: 0.8326911211743752
# Ratio of positive labels: 0.8328275252613342
# Ratio of positive labels: 0.8329403839676659
# Ratio of positive labels: 0.8330065776499113
# Ratio of positive labels: 0.8331305546865042
# Ratio of positive labels: 0.833207948982072
# Ratio of positive labels: 0.8332967248933538
# Ratio of positive labels: 0.8334083902033463
# Ratio of positive labels: 0.8334505945721503
# Ratio of positive labels: 0.8335272635107891
# Ratio of positive labels: 0.8335577266084395
# Ratio of positive labels: 0.8336915667636005
# Ratio of positive labels: 0.8337791758992434
# Ratio of positive labels: 0.8338436485820117
# Ratio of positive labels: 0.8339079735627313
# Ratio of positive labels: 0.8340408004485075
# Ratio of positive labels: 0.834173323733443
# Ratio of positive labels: 0.8342598828780493
# Ratio of positive labels: 0.8343690493837015
# Ratio of positive labels: 0.8344893566132504
# Ratio of positive labels: 0.8345638843699161
# Ratio of positive labels: 0.8346155157327758
# Ratio of positive labels: 0.8346556792771932
# Ratio of positive labels: 0.8346957517488464
# Ratio of positive labels: 0.8347697081573255
# Ratio of positive labels: 0.8347756247101277
# Ratio of positive labels: 0.8348606230438074
# Ratio of positive labels: 0.8349228564011693
# Ratio of positive labels: 0.8350074970969887
# Ratio of positive labels: 0.8350919471627571
# Ratio of positive labels: 0.835198704176556
# Ratio of positive labels: 0.8352378063167829
# Ratio of positive labels: 0.8353329367796096
# Ratio of positive labels: 0.8354278539478257
# Ratio of positive labels: 0.8355113604550901
# Ratio of positive labels: 0.8356394223778257
# Ratio of positive labels: 0.8357225058937889
# Ratio of positive labels: 0.8358277251369962
# Ratio of positive labels: 0.8359215616325347
# Ratio of positive labels: 0.8359929176735226
# Ratio of positive labels: 0.8361197317048754
# Ratio of positive labels: 0.8362351529427451
# Ratio of positive labels: 0.8363170220086348
# Ratio of positive labels: 0.8364097959002672
# Ratio of positive labels: 0.8365134383893866
# Ratio of positive labels: 0.8365947279344255
# Ratio of positive labels: 0.8366979370393697
# Ratio of positive labels: 0.8368119557179281
# Ratio of positive labels: 0.836947773453435
# Ratio of positive labels: 0.8370282265613814
# Ratio of positive labels: 0.8371305046149107
# Ratio of positive labels: 0.8372875023351392
# Ratio of positive labels: 0.8373563407646458
# Ratio of positive labels: 0.8374030986502341
# Ratio of positive labels: 0.8374497541100316
# Ratio of positive labels: 0.8375510114768985
# Ratio of positive labels: 0.8376301898339908
# Ratio of positive labels: 0.8376873614916868
# Ratio of positive labels: 0.8378316485098308
# Ratio of positive labels: 0.8379102624154421
# Ratio of positive labels: 0.8379778239627426
# Ratio of positive labels: 0.8380343691916392
# Ratio of positive labels: 0.838112506921749
# Ratio of positive labels: 0.8382338586349389
# Ratio of positive labels: 0.8382682744498976
# Ratio of positive labels: 0.8383459053473448
# Ratio of positive labels: 0.838488232559648
# Ratio of positive labels: 0.8385762572758394
# Ratio of positive labels: 0.8386856668212856
# Ratio of positive labels: 0.8387840648268876
# Ratio of positive labels: 0.8388607227048148
# Ratio of positive labels: 0.8389264631563101
# Ratio of positive labels: 0.8390457674998121
# Ratio of positive labels: 0.8390897093378826
# Ratio of positive labels: 0.8391121209847697
# Ratio of positive labels: 0.8392094303058854
# Ratio of positive labels: 0.8392851413353868
# Ratio of positive labels: 0.8393606905909125
# Ratio of positive labels: 0.8394680953244896
# Ratio of positive labels: 0.8395219667167727
# Ratio of positive labels: 0.8395863728820779
# Ratio of positive labels: 0.8396187274603462
# Ratio of positive labels: 0.8396722670322313
# Ratio of positive labels: 0.8397363085317565
# Ratio of positive labels: 0.8398320272319487
# Ratio of positive labels: 0.8399275431404328
# Ratio of positive labels: 0.8400228569009852
# Ratio of positive labels: 0.8400756863035275
# Ratio of positive labels: 0.8401812018880477
# Ratio of positive labels: 0.8402864948681976
# Ratio of positive labels: 0.8403494167606242
# Ratio of positive labels: 0.8404543110072525
# Ratio of positive labels: 0.8405694997949549
# Ratio of positive labels: 0.8406634384092604
# Ratio of positive labels: 0.8407886590906706
# Ratio of positive labels: 0.840882171046425
# Ratio of positive labels: 0.8409650160731301
# Ratio of positive labels: 0.841026767502432
# Ratio of positive labels: 0.8410779406693765
# Ratio of positive labels: 0.8412020751349151
# Ratio of positive labels: 0.8412946684601829
# Ratio of positive labels: 0.8414495682336642
# Ratio of positive labels: 0.8415521170435272
# Ratio of positive labels: 0.8416336628517375
# Ratio of positive labels: 0.8417254234120103
# Ratio of positive labels: 0.8418169935996515
# Ratio of positive labels: 0.841960186941068
# Ratio of positive labels: 0.8420306208010269
# Ratio of positive labels: 0.8420698855234175
# Ratio of positive labels: 0.8421193995929794
# Ratio of positive labels: 0.842189451089256
# Ratio of positive labels: 0.8422387398068061
# Ratio of positive labels: 0.8423188226691796
# Ratio of positive labels: 0.8423781648336951
# Ratio of positive labels: 0.8424373850217367
# Ratio of positive labels: 0.8424964836089979
# Ratio of positive labels: 0.8425657172746946
# Ratio of positive labels: 0.8426553006629031
# Ratio of positive labels: 0.8427344653585941
# Ratio of positive labels: 0.8427930184762937
# Ratio of positive labels: 0.8428616663772587
# Ratio of positive labels: 0.842950582136917
# Ratio of positive labels: 0.8429883487426224
# Ratio of positive labels: 0.8431176871925948
# Ratio of positive labels: 0.8432060711488184
# Ratio of positive labels: 0.8432942754646803
# Ratio of positive labels: 0.8433619963249104
# Ratio of positive labels: 0.8434802892465594
# Ratio of positive labels: 0.8435679476398416
# Ratio of positive labels: 0.8436655499438265
# Ratio of positive labels: 0.8437528437528438
# Ratio of positive labels: 0.8438096584882981
# Ratio of positive labels: 0.8439269028566816
# Ratio of positive labels: 0.8440439108476729
# Ratio of positive labels: 0.8441103312151942
# Ratio of positive labels: 0.8442067987243589
# Ratio of positive labels: 0.8442829720304319
# Ratio of positive labels: 0.8443288722000784
# Ratio of positive labels: 0.8443947402734175
# Ratio of positive labels: 0.8444905361669722
# Ratio of positive labels: 0.8445561105494439
# Ratio of positive labels: 0.8446415535844641
# Ratio of positive labels: 0.8446868662650723
# Ratio of positive labels: 0.8447221085617908
# Ratio of positive labels: 0.8448270705177416
# Ratio of positive labels: 0.8449119032678958
# Ratio of positive labels: 0.8449667167490871
# Ratio of positive labels: 0.8450512420353674
# Ratio of positive labels: 0.8450760171199889
# Ratio of positive labels: 0.8451305046576919
# Ratio of positive labels: 0.8452146163070733
# Ratio of positive labels: 0.8453084622924526
# Ratio of positive labels: 0.8453922315308454
# Ratio of positive labels: 0.8454165472673195
# Ratio of positive labels: 0.8454408149968905
# Ratio of positive labels: 0.8454847585329534
# Ratio of positive labels: 0.845548319720988
# Ratio of positive labels: 0.8456215982126161
# Ratio of positive labels: 0.8457045653435069
# Ratio of positive labels: 0.8457677233033074
# Ratio of positive labels: 0.8457816900717363
# Ratio of positive labels: 0.8458446485818767
# Ratio of positive labels: 0.8458683068726065
# Ratio of positive labels: 0.8459506267061966
# Ratio of positive labels: 0.8460523357542937
# Ratio of positive labels: 0.8461440806242126
# Ratio of positive labels: 0.8462454024838783
# Ratio of positive labels: 0.8463172873558737
# Ratio of positive labels: 0.8463987692427533
# Ratio of positive labels: 0.8464606375424364
# Ratio of positive labels: 0.8465029494368373
# Ratio of positive labels: 0.8465548878166231
# Ratio of positive labels: 0.8466455223518685
# Ratio of positive labels: 0.8467650507262526
# Ratio of positive labels: 0.8468843476829847
# Ratio of positive labels: 0.8469744006344233
# Ratio of positive labels: 0.8470449560873808
# Ratio of positive labels: 0.8470864180847675
# Ratio of positive labels: 0.8471567294433033
# Ratio of positive labels: 0.8472365391470217
# Ratio of positive labels: 0.8473354443171865
# Ratio of positive labels: 0.8474149287026086
# Ratio of positive labels: 0.8474942603817447
# Ratio of positive labels: 0.847592633468009
# Ratio of positive labels: 0.8477004055569937
# Ratio of positive labels: 0.8477696573787608
# Ratio of positive labels: 0.8478387766624242
# Ratio of positive labels: 0.8478790833739639
# Ratio of positive labels: 0.8479861701416415
# Ratio of positive labels: 0.8480835106535243
# Ratio of positive labels: 0.8481615999847475
# Ratio of positive labels: 0.8482776354510909
# Ratio of positive labels: 0.8483744207952351
# Ratio of positive labels: 0.8484615165255083
# Ratio of positive labels: 0.8485294536614088
# Ratio of positive labels: 0.8486257246136185
# Ratio of positive labels: 0.8487123344802419
# Ratio of positive labels: 0.8487987803145803
# Ratio of positive labels: 0.8488661412853237
# Ratio of positive labels: 0.8489522783338532
# Ratio of positive labels: 0.8490193671447862
# Ratio of positive labels: 0.8491240648673126
# Ratio of positive labels: 0.8491720153438704
# Ratio of positive labels: 0.8492575399478348
# Ratio of positive labels: 0.8493429036415462
# Ratio of positive labels: 0.8494657005103335
# Ratio of positive labels: 0.8495319292776594
# Ratio of positive labels: 0.8496543184397894
# Ratio of positive labels: 0.8497015023289378
# Ratio of positive labels: 0.8497954139006189
# Ratio of positive labels: 0.8498610864257584
# Ratio of positive labels: 0.8499359819067112
# Ratio of positive labels: 0.8500014005471471
# Ratio of positive labels: 0.8500387123254447
# Ratio of positive labels: 0.8501039132906497
# Ratio of positive labels: 0.8501596819396467
# Ratio of positive labels: 0.8502153468339829
# Ratio of positive labels: 0.8502709082629344
# Ratio of positive labels: 0.8503727913389848
# Ratio of positive labels: 0.8504559326907913
# Ratio of positive labels: 0.850520384426465
# Ratio of positive labels: 0.8506124943287562
# Ratio of positive labels: 0.8506859326000684
# Ratio of positive labels: 0.8507407510096949
# Ratio of positive labels: 0.8507954681858894
# Ratio of positive labels: 0.8508685344231142
# Ratio of positive labels: 0.8509783319969402
# Ratio of positive labels: 0.8510695113304666
# Ratio of positive labels: 0.8511145251653619
# Ratio of positive labels: 0.8511686473469913
# Ratio of positive labels: 0.8512410354358546
# Ratio of positive labels: 0.8513224649315144
# Ratio of positive labels: 0.851376247697088
# Ratio of positive labels: 0.8514207745350317
# Ratio of positive labels: 0.8515018160858546
# Ratio of positive labels: 0.8515004433231872
# Ratio of positive labels: 0.8515995287714268
# Ratio of positive labels: 0.8516619373910822
# Ratio of positive labels: 0.8517789263543633
# Ratio of positive labels: 0.8518319505286837
# Ratio of positive labels: 0.8519121755034076
# Ratio of positive labels: 0.8519922546158671
# Ratio of positive labels: 0.8520631056938629
# Ratio of positive labels: 0.8521519768423154
# Ratio of positive labels: 0.8522406868478074
# Ratio of positive labels: 0.8523473519261601
# Ratio of positive labels: 0.8523542773368566
# Ratio of positive labels: 0.8524244807913129
# Ratio of positive labels: 0.8524764907272744
# Ratio of positive labels: 0.8525645075405457
# Ratio of positive labels: 0.8525892462646866
# Ratio of positive labels: 0.8526319582706462
# Ratio of positive labels: 0.8526475909307747
# Ratio of positive labels: 0.852681180924632
# Ratio of positive labels: 0.8527686184311013
# Ratio of positive labels: 0.8528469223795119
# Ratio of positive labels: 0.8529340544030996
# Ratio of positive labels: 0.8530210302775064
# Ratio of positive labels: 0.8530809930081199
# Ratio of positive labels: 0.8531408484718384
# Ratio of positive labels: 0.8532005969562381
# Ratio of positive labels: 0.853287024222998
# Ratio of positive labels: 0.8533286946592805
# Ratio of positive labels: 0.8534059411235194
# Ratio of positive labels: 0.8535186685781961
# Ratio of positive labels: 0.853560021707992
# Ratio of positive labels: 0.8536190789415206
# Ratio of positive labels: 0.8536869121943855
# Ratio of positive labels: 0.8537368789984118
# Ratio of positive labels: 0.8538133527185042
# Ratio of positive labels: 0.8538985482856662
# Ratio of positive labels: 0.8539481951487154
# Ratio of positive labels: 0.8540065958744839
# Ratio of positive labels: 0.8541002287965654
# Ratio of positive labels: 0.8541583922471999
# Ratio of positive labels: 0.8542164531176973
# Ratio of positive labels: 0.8542920326693156
# Ratio of positive labels: 0.8543498736806894
# Ratio of positive labels: 0.8544427929393761
# Ratio of positive labels: 0.854465250744721
# Ratio of positive labels: 0.854478889561988
# Ratio of positive labels: 0.8545802229805002
# Ratio of positive labels: 0.8546287937879598
# Ratio of positive labels: 0.8546772795334542
# Ratio of positive labels: 0.8547344292700851
# Ratio of positive labels: 0.8547914790954625
# Ratio of positive labels: 0.8548396957231814
# Ratio of positive labels: 0.8549227319133341
# Ratio of positive labels: 0.8549794683568582
# Ratio of positive labels: 0.8550273952317489
# Ratio of positive labels: 0.8551187544059669
# Ratio of positive labels: 0.855201259119486
# Ratio of positive labels: 0.8552836204724547
# Ratio of positive labels: 0.8553484778777962
# Ratio of positive labels: 0.8553698580237812
# Ratio of positive labels: 0.8554518591693313
# Ratio of positive labels: 0.8554904286542974
# Ratio of positive labels: 0.8555808340758297
# Ratio of positive labels: 0.8556278683848887
# Ratio of positive labels: 0.8556920924689769
# Ratio of positive labels: 0.8557993459935634
# Ratio of positive labels: 0.8558719321385161
# Ratio of positive labels: 0.8559357800535741
# Ratio of positive labels: 0.8560167296322752
# Ratio of positive labels: 0.8560631464905719
# Ratio of positive labels: 0.8561610295444197
# Ratio of positive labels: 0.8562501609428246
# Ratio of positive labels: 0.856296258179604
# Ratio of positive labels: 0.8563936898569849
# Ratio of positive labels: 0.8564567084185923
# ...
# Ratio of positive labels: 0.9503192217577774
# Ratio of positive labels: 0.9503222674989559
# Ratio of positive labels: 0.9503273647369539
# Ratio of positive labels: 0.9503283571064357
# Ratio of positive labels: 0.9503303751227173
# Ratio of positive labels: 0.9503354699605396
# Ratio of positive labels: 0.9503385124733206
# Ratio of positive labels: 0.9503395032924794
# Ratio of positive labels: 0.9503415193380647
# Ratio of positive labels: 0.9503445602947193
# Ratio of positive labels: 0.9503455501891017
# Ratio of positive labels: 0.9503475649948078
# Ratio of positive labels: 0.9503485543782756
# Ratio of positive labels: 0.950353643175522
# Ratio of positive labels: 0.9503566813315419
# Ratio of positive labels: 0.9503566447826163
# Ratio of positive labels: 0.9503586574194084
# Ratio of positive labels: 0.9503606696438176
# Ratio of positive labels: 0.9503657545935724
# Ratio of positive labels: 0.9503667414045464
# Ratio of positive labels: 0.950370800521507
# Ratio of positive labels: 0.9503748588071083
# Ratio of positive labels: 0.9503778923019739
# Ratio of positive labels: 0.9503778536112895
# Ratio of positive labels: 0.9503819099284296
# Ratio of positive labels: 0.950385965415124
# Ratio of positive labels: 0.9503889965312216
# Ratio of positive labels: 0.9503899801555827
# Ratio of positive labels: 0.9503878935858641
# Ratio of positive labels: 0.9503878538955757
# Ratio of positive labels: 0.950391906699502
# Ratio of positive labels: 0.9503939126404986
# Ratio of positive labels: 0.9503989869077466
# Ratio of positive labels: 0.9503979232914767
# Ratio of positive labels: 0.9504009507046934
# Ratio of positive labels: 0.9504050000971469
# Ratio of positive labels: 0.9504080261676624
# Ratio of positive labels: 0.9504120740087169
# Ratio of positive labels: 0.9504171433069482
# Ratio of positive labels: 0.9504191450279618
# Ratio of positive labels: 0.9504231904914243
# Ratio of positive labels: 0.9504251911852926
# Ratio of positive labels: 0.9504271914702723
# Ratio of positive labels: 0.9504302131090088
# Ratio of positive labels: 0.9504332341303289
# Ratio of positive labels: 0.9504331898731332
# Ratio of positive labels: 0.9504372314226441
# Ratio of positive labels: 0.9504402508015005
# Ratio of positive labels: 0.9504402058412931
# Ratio of positive labels: 0.9504432242997811
# Ratio of positive labels: 0.9504462421418806
# Ratio of positive labels: 0.9504513012237864
# Ratio of positive labels: 0.9504522759776685
# Ratio of positive labels: 0.9504532505325605
# Ratio of positive labels: 0.9504562661193446
# Ratio of positive labels: 0.9504572400681294
# Ratio of positive labels: 0.9504602546323933
# Ratio of positive labels: 0.9504622482784938
# Ratio of positive labels: 0.9504652617167295
# Ratio of positive labels: 0.9504692946350152
# Ratio of positive labels: 0.9504733267305929
# Ratio of positive labels: 0.9504753182301701
# Ratio of positive labels: 0.9504783291063338
# Ratio of positive labels: 0.9504782803321298
# Ratio of positive labels: 0.9504812902923223
# Ratio of positive labels: 0.9504842996388014
# Ratio of positive labels: 0.9504852696378495
# Ratio of positive labels: 0.950489297228318
# Ratio of positive labels: 0.9504933239978353
# Ratio of positive labels: 0.950493273725391
# Ratio of positive labels: 0.9504962803176276
# Ratio of positive labels: 0.950501323992538
# Ratio of positive labels: 0.9505053478959373
# Ratio of positive labels: 0.9505063150592695
# Ratio of positive labels: 0.9505093190982694
# Ratio of positive labels: 0.9505143593906107
# Ratio of positive labels: 0.950517361998613
# Ratio of positive labels: 0.950518327544723
# Ratio of positive labels: 0.950521329137315
# Ratio of positive labels: 0.9505253481366709
# Ratio of positive labels: 0.9505273304892808
# Ratio of positive labels: 0.9505313480596966
# Ratio of positive labels: 0.9505333293981992
# Ratio of positive labels: 0.9505363279369818
# Ratio of positive labels: 0.9505362733656152
# Ratio of positive labels: 0.9505372362018149
# Ratio of positive labels: 0.950536164256191
# Ratio of positive labels: 0.9505381440970968
# Ratio of positive labels: 0.9505421577073253
# Ratio of positive labels: 0.950541085588238
# Ratio of positive labels: 0.9505410305663712
# Ratio of positive labels: 0.9505399587799097
# Ratio of positive labels: 0.950541937228612
# Ratio of positive labels: 0.9505439152750683
# Ratio of positive labels: 0.9505469093851298
# Ratio of positive labels: 0.9505478701617337
# Ratio of positive labels: 0.9505528957795775
# Ratio of positive labels: 0.9505569042201969
# Ratio of positive labels: 0.9505578636884132
# Ratio of positive labels: 0.9505588229616754
# Ratio of positive labels: 0.9505597820400427
# Ratio of positive labels: 0.9505607409235745
# Ratio of positive labels: 0.9505627152521682
# Ratio of positive labels: 0.9505646891797611
# Ratio of positive labels: 0.9505686935736255
# Ratio of positive labels: 0.9505706664933836
# Ratio of positive labels: 0.9505716237851535
# Ratio of positive labels: 0.9505756262555819
# Ratio of positive labels: 0.9505796279134917
# Ratio of positive labels: 0.9505785541677112
# Ratio of positive labels: 0.9505825547163033
# Ratio of positive labels: 0.9505855397407004
# Ratio of positive labels: 0.9505875095500106
# Ratio of positive labels: 0.950589478959644
# Ratio of positive labels: 0.9505914479697221
# Ratio of positive labels: 0.9505934165803666
# Ratio of positive labels: 0.9505933563961902
# Ratio of positive labels: 0.9505963385089357
# Ratio of positive labels: 0.9505993200169134
# Ratio of positive labels: 0.9506012870310382
# Ratio of positive labels: 0.9506062950057836
# Ratio of positive labels: 0.9506092745977957
# Ratio of positive labels: 0.950612253585796
# Ratio of positive labels: 0.950612191535227
# Ratio of positive labels: 0.9506131428727778
# Ratio of positive labels: 0.9506120674718133
# Ratio of positive labels: 0.9506130186291605
# Ratio of positive labels: 0.9506159957289072
# Ratio of positive labels: 0.9506189722255144
# Ratio of positive labels: 0.9506229609815041
# Ratio of positive labels: 0.9506249234100431
# Ratio of positive labels: 0.9506238474695216
# Ratio of positive labels: 0.9506227717468897
# Ratio of positive labels: 0.9506277709549752
# Ratio of positive labels: 0.9506307444515646
# Ratio of positive labels: 0.9506327050989927
# Ratio of positive labels: 0.9506356774942536
# Ratio of positive labels: 0.9506406733724588
# Ratio of positive labels: 0.9506416204800441
# Ratio of positive labels: 0.9506445910709389
# Ratio of positive labels: 0.9506455375905124
# Ratio of positive labels: 0.9506485071841101
# Ratio of positive labels: 0.9506534992378118
# Ratio of positive labels: 0.9506574788535664
# Ratio of positive labels: 0.9506594350127073
# Ratio of positive labels: 0.9506613907762254
# Ratio of positive labels: 0.9506623350229171
# Ratio of positive labels: 0.9506673231550671
# Ratio of positive labels: 0.9506672556942422
# Ratio of positive labels: 0.9506671882470552
# Ratio of positive labels: 0.9506681315260446
# Ratio of positive labels: 0.9506731170559707
# Ratio of positive labels: 0.9506760805617618
# Ratio of positive labels: 0.9506800538748571
# Ratio of positive labels: 0.9506809954728274
# Ratio of positive labels: 0.9506839572846173
# Ratio of positive labels: 0.9506889386980417
# Ratio of positive labels: 0.950689879113343
# Ratio of positive labels: 0.9506908193386999
# Ratio of positive labels: 0.95069175937417
# Ratio of positive labels: 0.9506947186038787
# Ratio of positive labels: 0.9506996964162581
# Ratio of positive labels: 0.9507026542472701
# Ratio of positive labels: 0.9507046020948803
# Ratio of positive labels: 0.9507075588337113
# Ratio of positive labels: 0.9507105149757645
# Ratio of positive labels: 0.9507144796019379
# Ratio of positive labels: 0.9507174344491631
# Ratio of positive labels: 0.9507224064543922
# Ratio of positive labels: 0.9507253599058207
# Ratio of positive labels: 0.9507283127614355
# Ratio of positive labels: 0.9507292478777127
# Ratio of positive labels: 0.9507301828053825
# Ratio of positive labels: 0.9507331342814014
# Ratio of positive labels: 0.9507370934290246
# Ratio of positive labels: 0.9507400436132235
# Ratio of positive labels: 0.9507419851391279
# Ratio of positive labels: 0.9507469501593083
# Ratio of positive labels: 0.950748890597772
# Ratio of positive labels: 0.9507528461626059
# Ratio of positive labels: 0.9507578085874561
# Ratio of positive labels: 0.9507617624566626
# Ratio of positive labels: 0.950763700620894
# Ratio of positive labels: 0.9507686604526439
# Ratio of positive labels: 0.9507665685268246
# Ratio of positive labels: 0.9507685056214064
# Ratio of positive labels: 0.9507714493741698
# Ratio of positive labels: 0.9507743925340927
# Ratio of positive labels: 0.9507753214102684
# Ratio of positive labels: 0.9507772568435953
# Ratio of positive labels: 0.950779191887264
# Ratio of positive labels: 0.9507821330829058
# Ratio of positive labels: 0.9507840672463092
# Ratio of positive labels: 0.950781975664712
# Ratio of positive labels: 0.9507839094547097
# Ratio of positive labels: 0.9507858428555762
# Ratio of positive labels: 0.9507877758674287
# Ratio of positive labels: 0.9507866906883707
# Ratio of positive labels: 0.9507835940619653
# Ratio of positive labels: 0.9507875381800883
# Ratio of positive labels: 0.950787458982845
# Ratio of positive labels: 0.9507914019191535
# Ratio of positive labels: 0.950793333205979
# Ratio of positive labels: 0.9507962694317187
# Ratio of positive labels: 0.950800210293315
# Ratio of positive labels: 0.9508021401124332
# Ratio of positive labels: 0.9508040695436487
# Ratio of positive labels: 0.9508080084333148
# Ratio of positive labels: 0.9508119465314042
# Ratio of positive labels: 0.9508138743957858
# Ratio of positive labels: 0.950813792632316
# Ratio of positive labels: 0.9508157199239378
# Ratio of positive labels: 0.9508196556652715
# Ratio of positive labels: 0.9508225862984973
# Ratio of positive labels: 0.9508255163431247
# Ratio of positive labels: 0.9508284457993315
# Ratio of positive labels: 0.9508323786823507
# Ratio of positive labels: 0.9508353068614528
# Ratio of positive labels: 0.9508362268257109
# Ratio of positive labels: 0.9508391540307598
# Ratio of positive labels: 0.950842080648253
# Ratio of positive labels: 0.9508429996557957
# Ratio of positive labels: 0.9508439184789098
# Ratio of positive labels: 0.95084684373749
# Ratio of positive labels: 0.9508487651998744
# Ratio of positive labels: 0.9508506862767717
# Ratio of positive labels: 0.9508516039602769
# Ratio of positive labels: 0.9508485098299971
# Ratio of positive labels: 0.9508514331614188
# Ratio of positive labels: 0.9508533532002875
# Ratio of positive labels: 0.9508562754599204
# Ratio of positive labels: 0.9508612021441583
# Ratio of positive labels: 0.9508641230311518
# Ratio of positive labels: 0.9508680456369193
# Ratio of positive labels: 0.9508689608448979
# Ratio of positive labels: 0.9508718800762801
# Ratio of positive labels: 0.9508737967196426
# Ratio of positive labels: 0.9508737091737209
# Ratio of positive labels: 0.9508776288543089
# Ratio of positive labels: 0.9508805460477351
# Ratio of positive labels: 0.9508804578521055
# Ratio of positive labels: 0.9508843756791431
# Ratio of positive labels: 0.9508872913205575
# Ratio of positive labels: 0.9508882037767059
# Ratio of positive labels: 0.9508931208519015
# Ratio of positive labels: 0.9508980369425999
# Ratio of positive labels: 0.950898948049101
# Ratio of positive labels: 0.9509008598730259
# Ratio of positive labels: 0.9509047729135579
# Ratio of positive labels: 0.9509076844714456
# Ratio of positive labels: 0.9509125966453906
# Ratio of positive labels: 0.9509125053401647
# Ratio of positive labels: 0.9509174160490036
# Ratio of positive labels: 0.9509193248781386
# Ratio of positive labels: 0.9509212333254318
# Ratio of positive labels: 0.9509241414900075
# Ratio of positive labels: 0.950926049073951
# Ratio of positive labels: 0.9509289561754263
# Ratio of positive labels: 0.9509318626955982
# Ratio of positive labels: 0.9509337689355504
# Ratio of positive labels: 0.9509366743935682
# Ratio of positive labels: 0.9509385797715345
# Ratio of positive labels: 0.950943482966737
# Ratio of positive labels: 0.9509443879840233
# Ratio of positive labels: 0.950947291219733
# Ratio of positive labels: 0.9509491947755073
# Ratio of positive labels: 0.9509471019509471
# Ratio of positive labels: 0.950949005145335
# Ratio of positive labels: 0.9509509079595406
# Ratio of positive labels: 0.9509548077950586
# Ratio of positive labels: 0.9509577082507407
# Ratio of positive labels: 0.9509606081272011
# Ratio of positive labels: 0.9509625090230541
# Ratio of positive labels: 0.9509634112374851
# Ratio of positive labels: 0.950966309676273
# Ratio of positive labels: 0.9509682094338662
# Ratio of positive labels: 0.9509721048182587
# Ratio of positive labels: 0.9509740036183978
# Ratio of positive labels: 0.9509768998434446
# Ratio of positive labels: 0.9509787977862937
# Ratio of positive labels: 0.9509826905599655
# Ratio of positive labels: 0.9509815950308279
# Ratio of positive labels: 0.9509844893432183
# Ratio of positive labels: 0.9509863857720298
# Ratio of positive labels: 0.9509892790294385
# Ratio of positive labels: 0.9509881832803039
# Ratio of positive labels: 0.9509910757815795
# Ratio of positive labels: 0.9509939677061432
# Ratio of positive labels: 0.9509928718173127
# Ratio of positive labels: 0.9509937695666605
# Ratio of positive labels: 0.9509956637475945
# Ratio of positive labels: 0.9509945680173711
# Ratio of positive labels: 0.9509964617412697
# Ratio of positive labels: 0.9510003477131138
# Ratio of positive labels: 0.9510012442705277
# Ratio of positive labels: 0.9510041328776443
# Ratio of positive labels: 0.9510050288794533
# Ratio of positive labels: 0.9510099083657919
# Ratio of positive labels: 0.9510137910637412
# Ratio of positive labels: 0.9510156815536378
# Ratio of positive labels: 0.9510175716670931
# Ratio of positive labels: 0.9510194614042196
# Ratio of positive labels: 0.9510233416052741
# Ratio of positive labels: 0.9510232397499355
# Ratio of positive labels: 0.9510261235806892
# Ratio of positive labels: 0.9510260214687815
# Ratio of positive labels: 0.9510298994727369
# Ratio of positive labels: 0.9510327817801395
# Ratio of positive labels: 0.9510356635140633
# Ratio of positive labels: 0.951039539401632
# Ratio of positive labels: 0.9510414252621591
# Ratio of positive labels: 0.951044305276673
# Ratio of positive labels: 0.9510451958579993
# Ratio of positive labels: 0.9510480749248534
# Ratio of positive labels: 0.9510519476516727
# Ratio of positive labels: 0.9510548254748727
# Ratio of positive labels: 0.9510557146563473
# Ratio of positive labels: 0.9510585915330568
# Ratio of positive labels: 0.9510574924890752
# Ratio of positive labels: 0.9510573874019801
# Ratio of positive labels: 0.9510592696151932
# Ratio of positive labels: 0.951061151454395
# Ratio of positive labels: 0.9510620394774096
# Ratio of positive labels: 0.9510639206676064
# Ratio of positive labels: 0.9510667947290478
# Ratio of positive labels: 0.9510666887807242
# Ratio of positive labels: 0.951066582853443
# Ratio of positive labels: 0.9510694557944039
# Ratio of positive labels: 0.9510723281648846
# Ratio of positive labels: 0.9510751999650552
# Ratio of positive labels: 0.9510760858883404
# Ratio of positive labels: 0.951075979080914
# Ratio of positive labels: 0.9510778572073668
# Ratio of positive labels: 0.9510797349610648
# Ratio of positive labels: 0.9510816123421191
# Ratio of positive labels: 0.951084481511577
# Ratio of positive labels: 0.9510883421742637
# Ratio of positive labels: 0.9510922020710226
# Ratio of positive labels: 0.9510950693363724
# Ratio of positive labels: 0.9510999195676688
# Ratio of positive labels: 0.9511037771680115
# Ratio of positive labels: 0.9511076340033376
# Ratio of positive labels: 0.951112481546221
# Ratio of positive labels: 0.9511153453798499
# Ratio of positive labels: 0.9511142435425818
# Ratio of positive labels: 0.9511151242787944
# Ratio of positive labels: 0.9511179869990218
# Ratio of positive labels: 0.9511208491518689
# Ratio of positive labels: 0.9511227198546177
# Ratio of positive labels: 0.9511245901866737
# Ratio of positive labels: 0.9511264601481473
# Ratio of positive labels: 0.9511293203275678
# Ratio of positive labels: 0.9511311894500897
# Ratio of positive labels: 0.9511300870257631
# Ratio of positive labels: 0.9511349265845449
# Ratio of positive labels: 0.9511377847927668

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# To properly model the expected degredation of a classifier, we have to assume some parametric form for both the classifier and the data. Let's assume that
#
# $$
#     \begin{equation}
#         p(y=0)=p(y=1)=0.5 \\
#         p(x | y = 0) = \mathcal{N}(-1, 1/4) \\
#         p(x | y = 1) = \mathcal{N}(1, 1/4)
#     \end{equation}
# $$
#
# We assume concrete value for the true mean and std for now, but will make these arbitrary later. Now we need to determine the right estimated mean, and std to make sure our NB classifier has a desired FPR. The decision boundary happens where $p(y = 0 | x) = p(y = 1 | x)$ which can be simplified to
#
# $$
#     \begin{align}
#         \frac{1}{\sigma_{0}} e^{-(\frac{x - \mu_{0}}{\sigma_{0}})^2} = \frac{1}{\sigma_{1}} e^{-(\frac{x - \mu_{1}}{\sigma_{1}})^2}
#     \end{align}
# $$
#
# We assume that $\sigma_{0} = \sigma_{1}$ otherwise the math gets very messy. Using this assumption, solving for $x$ gives $x = \frac{\mu_{0} + \mu_{1}}{2}$. Now if we fix $\overline{x}_1$ and, we know that using inverse Z table the value of the decision boundary to have a 1% FPR is $-0.4175$, then $\overline{x}_{0} = 2 * (-0.4175) - \overline{x}_{1}$. W.L.G. we can assume that $\overline{x}_{1} = \mu_{1}$ to get $\overline{x}_{0} = 2 * (-0.4175) - 1 = -1.8350$
#
# *** Scratch what was stated above for the solution of the decision boundary! The above solution assumes that the ratio of pos/neg samples stays constant, but by definition in our case it won't since we are adding noisy labels. Mind you, we keep the probability of *sampling* pos/neg classes constant, but their respective ratio in our dataset up to some point will not be the same. Here is the full solution
#
# $$
#     \begin{equation}
#         \mu_{0} = x +/- \sqrt{\mu_{1}^{2} -2\mu_{1}x + x^{2} - \sigma_{0}^2 \mathrm{Log} \frac{a}{b}}
#     \end{equation}
# $$
#
# though in our case, just the negative solution makes sense.
#
# So what happens when we get a new sample of data and want to update the model

# %%
from scipy.stats import norm

# %%
y0 = 0.5
y1 = 0.5

s0 = 1.0
s1 = 1.0

m0 = -1.0
m1 = 1.0

n = 100
sample_m0 = - 0.44
sample_m1 = m1

fpr = 0.1
gamma = 0.28

# %%
n_update = 1000000
cur_data_size = n
n_neg = y0 * n
n_pos = y1 * n

for i in range(100):
    
    sample_m0 = (n_update * (0.5 - fpr) * (m0) + (cur_data_size * p_neg) * sample_m0) / (n_update * (0.5 - fpr) + (cur_data_size * p_neg))
    sample_m1 = (n_update * (0.5*m1 + fpr * m0) + (cur_data_size * p_pos) * sample_m1) / (n_update * (0.5 + fpr) + (cur_data_size * p_pos))
    
    cur_data_size += n_update
    
    n_pos += n_update * (y1 + fpr)
    n_neg += n_update * (y0 - fpr)

    p_pos = n_pos / (cur_data_size)
    p_neg = n_neg / (cur_data_size)
    
    gamma = (sample_m0 ** 2 - sample_m1 ** 2 + (s0 ** 2) * np.log((p_neg / p_pos))) / (2 * (sample_m0 - sample_m1))
    
    fpr = 1.0 - norm.cdf((gamma - m0) / s0)

# %%
sample_m0
# Out:
# -0.9999994399088229

# %%
sample_m1
# Out:
# 0.507171520879883

# %%
gamma
# Out:
# -0.021188617905140057

# %%
p_neg
# Out:
# 0.3365054735810638

# %%
fpr
# Out:
# 0.16383659236537662

# %%
p_pos
# Out:
# 0.6634945264189359

# %%
n_pos = y1 * n + n_update * (y1 + fpr)
n_neg = y0 * n + n_update * (y0 - fpr)

p_pos = n_pos / (n + n_update)
p_neg = n_neg / (n + n_neg)

# %% [markdown]
# Now compute new decision boundary and it's FPR given the fact that our dataset is no longer balanced.

# %%
new_d = (sample_m0 ** 2 - sample_m1 ** 2 + (1.0 ** 2) * np.log((p_neg / p_pos))) / (2 * (sample_m0 - sample_m1))

# %%
new_d
# Out:
# 0.11420532090110772

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Let's do the same thing for LR that we did for our NB analysis. There is no closed form for LR, so we'll have to update using GD. We need to check that the gradient on a large sample of data is close to the expected gradient computed using numerical integration via mathematica

# %% [markdown]
# ### Gaussian Data

# %% [markdown]
# `sklearn.datasets.make_classification` creates data that is not quite normally distributed, so to ensure that the compounding FPR is not an artefact of that data, we first test it out on Gaussian data from distributions we define. We also look at how the number of features affects the rate at which the FPR compounds

# %%
import copy
import numpy as np
import torch
from sklearn.metrics import confusion_matrix
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
def make_gaussian_data(m0, m1, s0, s1, n, p0, p1, features=2, flip=0.0):
    neg_samples = np.random.multivariate_normal(m0 * np.ones(features), s0 * np.eye(features), int(n * p0))
    pos_samples = np.random.multivariate_normal(m1 * np.ones(features), s1 * np.eye(features), int(n * p1))
    
    x = np.concatenate((neg_samples, pos_samples))
    y = np.concatenate((np.zeros(len(neg_samples)), np.ones(len(pos_samples))))
    
    idx = np.random.choice(len(x), len(x), replace=False)
    x = x[idx]
    y = y[idx]
    
    return torch.from_numpy(x).float(), torch.from_numpy(y).float()

# %%
def eval_model(y, y_pred):
    c_matrix = confusion_matrix(y, y_pred)
    tn, fp, fn, tp = c_matrix.ravel()

    samples = float(len(y_pred))
    
    return tn / samples, fp / samples, fn / samples, tp / samples

# %%
def sigmoid(z):
    return 1.0 / (1 + torch.exp(-z))

# %%
def train(x_train, y_train):
    w = torch.from_numpy(np.random.randn(x_train.shape[1])).float()
    w.requires_grad = True
    b = torch.tensor(0.0, requires_grad=True).float()

    criterion = torch.nn.BCELoss()
    lr = 1.0

    for i in range(1000):
        out = sigmoid(torch.matmul(x_train, w) + b)

        loss = criterion(out, y_train)

        if i % 500 == 0:
            print(loss)

        loss.backward()
        w.data = w.data - lr * w.grad
        b.data = b.data - lr * b.grad

        w.grad.zero_()
        b.grad.zero_()
        
    return w, b

# %%
def update_model_online(w, b, num_updates):
    new_w = copy.deepcopy(w)
    new_b = copy.deepcopy(b)
    
    print(new_w.requires_grad)
    
    size = float(len(y_test1)) / float(num_updates)
    
    prediction_differences = []

    for i in range(num_updates):
        idx_start = int(size * i)
        idx_end = int(size * (i + 1))
        sub_x = x_test1[idx_start: idx_end, :]
        sub_y = copy.deepcopy(y_test1[idx_start: idx_end])

        sub_pred = sigmoid(torch.matmul(sub_x, new_w) + new_b)
        sub_pred_copy = copy.deepcopy(sub_pred.data)
        sub_pred_copy[sub_pred_copy >= 0.5] = 1
        sub_pred_copy[sub_pred_copy < 0.5] = 0
        
        fp_idx = np.logical_and(sub_y == 0, sub_pred_copy == 1)
        sub_y[fp_idx.bool()] = 1
        
        loss = criterion(sub_pred, sub_y)
        loss.backward()
        new_w.data = new_w.data - lr * new_w.grad
        new_b.data = new_b.data - lr * new_b.grad

        new_w.grad.zero_()
        new_b.grad.zero_()
        
    return new_w, new_b

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

# pos_idx = y_train[:1000] == 1
# pos_idx = np.where(pos_idx)
# neg_idx = y_train[:1000] == 0
# neg_idx = np.where(neg_idx)

# plt.scatter(x_train[pos_idx, 0].detach(), x_train[pos_idx, 1].detach(), label=1)
# plt.scatter(x_train[neg_idx, 0].detach(), x_train[neg_idx, 1].detach(), label=0)
# plt.legend()

# %%
m0 = -1
m1 = 1

s0 = 1
s1 = 1

n = 1000

p0 = 0.5
p1 = 1 - p0

n_features = 1

# %%
n_features = [1, 2, 3, 4, 5]
np.random.seed(1)

for n_feature in n_features:
    print("----- Gaussian data with {} features -----".format(n_feature))
    x_train, y_train = make_gaussian_data(m0 - 0.2, m1 - 0.1, s0, s1, n, p0, p1, features=n_feature)

    x_test1, y_test1 = make_gaussian_data(m0, m1, s0, s1, 1000000, p0, p1, features=n_feature)
    x_test2, y_test2 = make_gaussian_data(m0, m1, s0, s1, 1000000, p0, p1, features=n_feature)
    
    x_train.requires_grad = True
    x_test1.requires_grad = True
    
    w, b = train(x_train, y_train)

    y_pred = sigmoid(torch.matmul(x_test2, w) + b)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    tn, fp, fn, tp = eval_model(y_test2, y_pred.detach())
    
    print("Original TPR: {}".format(tp))
    print("Original FPR: {}".format(fp))
    print("Original TNR: {}".format(tn))
    print("Original FNR: {}".format(fn))
    
    new_w, new_b = update_model_online(w, b, 2000)
    
    y_pred = sigmoid(torch.matmul(x_test2, new_w) + new_b)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    tn, fp, fn, tp = eval_model(y_test2, y_pred.detach())
    
    print("Updated TPR: {}".format(tp))
    print("Updated FPR: {}".format(fp))
    print("Updated TNR: {}".format(tn))
    print("Updated FNR: {}".format(fn))
# Out:
# ----- Gaussian data with 1 features -----
# tensor(1.4887, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3334, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.431803
# Original FPR: 0.091434
# Original TNR: 0.408566
# Original FNR: 0.068197
# True
# Updated TPR: 0.495925
# Updated FPR: 0.325954
# Updated TNR: 0.174046
# Updated FNR: 0.004075
# ----- Gaussian data with 2 features -----
# tensor(0.3750, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.1513, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.470685
# Original FPR: 0.051921
# Original TNR: 0.448079
# Original FNR: 0.029315
# True
# Updated TPR: 0.48897
# Updated FPR: 0.103469
# Updated TNR: 0.396531
# Updated FNR: 0.01103
# ----- Gaussian data with 3 features -----
# tensor(2.0499, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0855, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.486886
# Original FPR: 0.031798
# Original TNR: 0.468202
# Original FNR: 0.013114
# True
# Updated TPR: 0.491653
# Updated FPR: 0.045363
# Updated TNR: 0.454637
# Updated FNR: 0.008347
# ----- Gaussian data with 4 features -----
# tensor(0.4456, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0642, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.493305
# Original FPR: 0.018757
# Original TNR: 0.481243
# Original FNR: 0.006695
# True
# Updated TPR: 0.494202
# Updated FPR: 0.021071
# Updated TNR: 0.478929
# Updated FNR: 0.005798
# ----- Gaussian data with 5 features -----
# tensor(2.7270, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0437, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.496496
# Original FPR: 0.01254
# Original TNR: 0.48746
# Original FNR: 0.003504
# True
# Updated TPR: 0.496467
# Updated FPR: 0.010668
# Updated TNR: 0.489332
# Updated FNR: 0.003533

# %% [markdown]
# ### `sklearn.make_classification` Data

# %%
n_features = [1, 2, 3, 4, 5]
np.random.seed(1)

for n_feature in n_features:
    print("----- sklearn data with {} features -----".format(n_feature))
    if n_feature > 1:
        n_clusters = 2
    else:
        n_clusters = 1

    x, y = make_classification(1000000, n_informative=n_feature, n_features=n_feature, n_classes=2, n_clusters_per_class=n_clusters ,n_redundant=0, flip_y=0.0, class_sep=1.0)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.99)
    x_test1, x_test2, y_test1, y_test2 = train_test_split(x_test, y_test, test_size=0.5)
    
    x_train, y_train = torch.from_numpy(x_train).float(), torch.from_numpy(y_train).float()
    x_test1, y_test1 = torch.from_numpy(x_test1).float(), torch.from_numpy(y_test1).float()
    x_test2, y_test2 = torch.from_numpy(x_test2).float(), torch.from_numpy(y_test2).float()
    
    x_train.requires_grad = True
    x_test1.requires_grad = True
    
    w, b = train(x_train, y_train)

    y_pred = sigmoid(torch.matmul(x_test2, w) + b)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    tn, fp, fn, tp = eval_model(y_test2, y_pred.detach())
    
    print("Original TPR: {}".format(tp))
    print("Original FPR: {}".format(fp))
    print("Original TNR: {}".format(tn))
    print("Original FNR: {}".format(fn))
    
    new_w, new_b = update_model_online(w, b, 2000)
    
    y_pred = sigmoid(torch.matmul(x_test2, new_w) + new_b)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    tn, fp, fn, tp = eval_model(y_test2, y_pred.detach())
    
    print("Updated TPR: {}".format(tp))
    print("Updated FPR: {}".format(fp))
    print("Updated TNR: {}".format(tn))
    print("Updated FNR: {}".format(fn))
# Out:
# ----- sklearn data with 1 features -----
# tensor(1.3298, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0403, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.5004181818181819
# Original FPR: 0.0011818181818181819
# Original TNR: 0.4983717171717172
# Original FNR: 2.8282828282828282e-05
# True
# Updated TPR: 0.5004121212121212
# Updated FPR: 0.0010686868686868686
# Updated TNR: 0.4984848484848485
# Updated FNR: 3.434343434343434e-05
# ----- sklearn data with 2 features -----
# tensor(1.1548, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2934, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.4347252525252525
# Original FPR: 0.044676767676767676
# Original TNR: 0.45546868686868686
# Original FNR: 0.06512929292929293
# True
# Updated TPR: 0.493220202020202
# Updated FPR: 0.31825454545454546
# Updated TNR: 0.1818909090909091
# Updated FNR: 0.0066343434343434345
# ----- sklearn data with 3 features -----
# tensor(1.0458, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5982, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.3804727272727273
# Original FPR: 0.17446666666666666
# Original TNR: 0.32535555555555556
# Original FNR: 0.11970505050505051
# True
# Updated TPR: 0.4993717171717172
# Updated FPR: 0.4029010101010101
# Updated TNR: 0.09692121212121212
# Updated FNR: 0.000806060606060606
# ----- sklearn data with 4 features -----
# tensor(0.6944, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.4784, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.38213535353535355
# Original FPR: 0.10082222222222222
# Original TNR: 0.4001212121212121
# Original FNR: 0.11692121212121212
# True
# Updated TPR: 0.49904848484848485
# Updated FPR: 0.5009414141414141
# Updated TNR: 2.02020202020202e-06
# Updated FNR: 8.08080808080808e-06
# ----- sklearn data with 5 features -----
# tensor(2.7463, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.3903, grad_fn=<BinaryCrossEntropyBackward>)
# Original TPR: 0.41310505050505053
# Original FPR: 0.06195151515151515
# Original TNR: 0.4386787878787879
# Original FNR: 0.08626464646464646
# True
# Updated TPR: 0.49936969696969696
# Updated FPR: 0.500630303030303
# Updated TNR: 0.0
# Updated FNR: 0.0
